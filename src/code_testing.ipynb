# %% [markdown]
# # Application Project - Computational Social Science

# %% [markdown]
# ## YouTube Channels Dataset Fetch

# %%
import utils.channel_utils as cu
import utils.video_utils as vu
import utils.write_utils as wu
import utils.__deprecated_legacy_utils as lu
from datetime import datetime

import pandas as pd
from pytube import Channel
import scrapetube
from utils.string_utils import find_between
import ssl
from tqdm import tqdm

from IPython.display import display
ssl._create_default_https_context = ssl._create_unverified_context

# %%
channel_ids = pd.read_csv('dataset/input_dataset/channel_ids.csv.gz', compression='gzip')

# %%
channel_ids, channel_ids.count(), type(channel_ids)
# Out:
# (                        channel_id
#  0         UCYt67-MBjYF5Y8RcEAjtq1g
#  1         UCYig0vJRD03a6lkqWrbP8xg
#  2         UCOTXKyzvDOqDGDKhuScHOag
#  3         UC4bEEVSvrNu0i7FQrCMNthw
#  4         UCgia4xeNJr_VfyNYSlCmWjg
#  ...                            ...
#  15597228  UCtVOGvJJGEqpcn4lZihjlHQ
#  15597229  UC9TDkg0OnsdDG5JWmecJuOQ
#  15597230  UC0SokC74Aa8HMXZi1Bf8ksw
#  15597231  UCbE0NjJ-j34J_V8MGuApzxw
#  15597232  UCoVghWAzj3_eDZHLjWxHmrQ
#
#  [15597233 rows x 1 columns],
#  channel_id    15597232
#  dtype: int64,
#  pandas.core.frame.DataFrame)

# %%
channel_ids_as_list = channel_ids['channel_id'].to_list()

# %% [markdown]
# ## Channel Attributes

# %% [markdown]
# ### Example for one youtube channel

# %%
#TEST
index = 79139
first_channel_id = channel_ids_as_list[index]
channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
channel_object = Channel(channel_url)
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[238], line 6
#       4 channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
#       5 channel_object = Channel(channel_url)
# ----> 6 channel_about_html = str(channel_object.about_html)
#       7 channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
#       8 channel_creation_date
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pytube/contrib/channel.py:134, in Channel.about_html(self)
#     132     return self._about_html
#     133 else:
# --> 134     self._about_html = request.get(self.about_url)
#     135     return self._about_html
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pytube/request.py:53, in get(url, extra_headers, timeout)
#      51 if extra_headers is None:
#      52     extra_headers = {}
# ---> 53 response = _execute_request(url, headers=extra_headers, timeout=timeout)
#      54 return response.read().decode("utf-8")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pytube/request.py:37, in _execute_request(url, method, headers, data, timeout)
#      35 else:
#      36     raise ValueError("Invalid URL")
# ---> 37 return urlopen(request, timeout=timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
#Get first 1 id from the id list
first_channel_id = channel_ids_as_list[78132]

#channel with most video uploads
# first_channel_id = "UCPF-oYb2-xN5FbCXy0167Gg"

# %%
# channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
channel_url = "https://www.youtube.com/channel/UCyuRxrUSsbxBRKTrI1Db3XA"
# channel_url = "https://www.youtube.com/channel/UCZvJUIAiQROopthP-KTtW7g"
# channel_url = "https://www.youtube.com/channel/UCasyWKltNuQ3bGn29Iep7TA"
channel_url
# Out:
# 'https://www.youtube.com/channel/UCyuRxrUSsbxBRKTrI1Db3XA'

# %%
channel_object = Channel(channel_url)

# %%
#Channel ID
channel_id = channel_object.channel_id
# channel_object.about_html

# %%
#Channel name
channel_object.channel_name
# Out:
# 'Reality of Life'

# %%
#Channel Description
channel_about_html = str(channel_object.about_html)
channel_description = find_between(channel_about_html, 'name="description" content="', '"><meta name="keywords"')
channel_description
# Out:
# 'Asalam o Alaikum!  Welcome to my Channel Reality of Life . This channel is all about High Power Motivational Videos , What&#39;s App Status , Poetry , Sad Poetry...'

# %%
with open("output_test.txt", "w") as file:
    # Write the string to the file
    file.write(channel_about_html)

# %%
#Channel Links
import json
channel_about_html = str(channel_object.about_html)
channels_links_as_string = find_between(channel_about_html, ',"links":', ',"displayCanonicalChannelUrl":')
try:
    channels_links_as_list = json.loads(channels_links_as_string)
except:
    channels_links_as_list = {}
channels_links_per_channel = []
for channel in channels_links_as_list:
    print(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")
    channels_links_per_channel.append(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")

# %%
#Channel yt api key might be important
channel_object.yt_api_key
# Out:
# 'AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8'

# %%
#Channel Subscribers
channel_about_html = str(channel_object.about_html)
channel_subscriber = find_between(channel_about_html, '"subscriberCountText":"', ' subscribers')
channel_subscriber
# Out:
# '2.03K'

# %%
#Channel Video Count
channel_about_html = str(channel_object.about_html)
channel_video_count = int(find_between(channel_about_html, ',"videoCountText":"', ' videos",').replace(',' , ''))
channel_video_count
# Out:
# 234

# %%
#Channel View Count
channel_about_html = str(channel_object.about_html)
channel_view_count = int(find_between(channel_about_html, ',"viewCountText":"', ' views",').replace(',' , ''))
channel_view_count
# Out:
# 472284

# %%
time_as_str = find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , '')

# %%
time_as_str
# Out:
# 'Jan 7 2023'

# %%
#Channel creation Date
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, 'joinedDateText":{"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2023, 1, 7, 0, 0)

# %%
# Open the file in read mode
with open('output.txt', 'r') as file:
    # Read the entire file into a variable
    content = file.read()

# Now you can use the 'content' variable
temp = content

# %%
#Channel creation Date
channel_about_html = str(temp)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2013, 4, 4, 0, 0)

# %%
#Channel Country
channel_about_html = str(channel_object.about_html)
channel_country = find_between(channel_about_html, '"country":"', '","')
channel_country
# Out:
# 'South Korea'

# %%
channel_object.channel_id, channel_object.channel_name, channel_description, channels_links_per_channel, channel_subscriber, videos_list_per_channel

# %% [markdown]
# ## Video Attributes

# %%
from pytube import YouTube

# %%
vide_url = "https://www.youtube.com/watch?v=NIq14KtuVaM"

# %%
video_object = YouTube(vide_url)

# %%
video_object.title, video_object.author, video_object.publish_date, video_object.thumbnail_url, video_object.length

# %% [markdown]
# ## ScrapeTube - Youtube Channel- Video By Sampling

# %%
def convert_time_to_seconds(time_string):
    # Split the time string by ':'
    time_parts = list(map(int, time_string.split(':')))
    
    # Initialize total_seconds
    total_seconds = 0

    # If the format is hh:mm:ss
    if len(time_parts) == 3:
        hours, minutes, seconds = time_parts
        total_seconds = (hours * 3600) + (minutes * 60) + seconds

    # If the format is mm:ss
    elif len(time_parts) == 2:
        minutes, seconds = time_parts
        total_seconds = (minutes * 60) + seconds

    # If the format is just seconds
    elif len(time_parts) == 1:
        total_seconds = time_parts[0]

    return total_seconds

# Example usage
time_strings = ["96:00:00", "12:00", "25"]

for time_string in time_strings:
    seconds = convert_time_to_seconds(time_string)
    print(f"{time_string} -> {seconds} seconds")


# Example usage
time_string = "96:00:00"
seconds = convert_time_to_seconds(time_string)
print(f"{time_string} -> {seconds} seconds")


def convert_views_to_int(view_string):
    # Remove non-numeric characters
    numeric_string = ''.join(filter(str.isdigit, view_string))
    # Convert the numeric string to an integer
    return int(numeric_string)

# Example usage
view_string = "15,218 views"
views = convert_views_to_int(view_string)
print(f"{view_string} -> {views} views")
# Out:
# 96:00:00 -> 345600 seconds
# 12:00 -> 720 seconds
# 25 -> 25 seconds
# 96:00:00 -> 345600 seconds
# 15,218 views -> 15218 views

# %%
trial_df = pd.read_csv('dataset/output_dataset/from_2000_until_10000_channels_list.csv.gz', compression='gzip')
channel_ids_df = trial_df[1160:1170]
threshold = 120
channel_ids_df
# Out:
#                     channel_id             channel_name  \
# 1160  UCpB9bqufOA0OyjA85cvywXg          Ugreen Official
# 1161  UCkNt3Uw0dF1-hi21--0-XOg                   Neldis
# 1162  UCcOEc4yI0pYoQUxuy1nd3lA           Devil Team 2.0
# 1163  UCnILyLwR92FZNcAVPAOfb0A  Все о Лучших Лигах Мира
# 1164  UCvC4D8onUfXzvjTOM-dBfEA     Marvel Entertainment
# 1165  UC9LQwHZoucFT94I2h6JOcjw             Liverpool FC
# 1166  UC6X38uj5Ea8duF6ce4rErtA                      NaN
# 1167  UCS5DStnMh7hQ9DnItrUpcFQ                Minayayoo
# 1168  UCaESFLed9_JbjDQRqAv2uHA  Cartoon Network Danmark
# 1169  UCr70rWBx70LsyDVC9aQHyOQ              Firewall154
#
#                                     channel_description  \
# 1160  Welcome to UGREEN, We produce【worry-free tech ...
# 1161  ➡️ Hello friendsPlease subscribe to help the c...
# 1162  Welcome to Devil team 2 0 Hello my dear youtub...
# 1163  Канал, посвященный Первой и Второй российским ...
# 1164  Marvel is committed to bringing great stories,...
# 1165  Get closer to the Reds than anyone else!Well, ...
# 1166                                                NaN
# 1167  Share your videos with friends, family, and th...
# 1168  Velkommen til den officielle danske Cartoon Ne...
# 1169  🔥 Código &#39;&#39;FIREWALL154&#39;&#39; na lo...
#
#                                           channel_links  channel_video_count  \
# 1160  ['Linktree: linktr.ee/UgreenLtd', 'Facebook: f...                473.0
# 1161                                                 []                826.0
# 1162                                                 []                365.0
# 1163  ['Поддержка канала: donationalerts.com/r/besti...                772.0
# 1164  ['Marvel.com: marvel.com', 'Twitter: twitter.c...               9097.0
# 1165  ['SUBSCRIBE FOR FREE!: youtube.com/subscriptio...               6767.0
# 1166                                                NaN                  NaN
# 1167                                                 []                145.0
# 1168  ['cartoonnetwork.dk: cartoonnetwork.dk', 'FB: ...               2415.0
# 1169  ['Twitch: twitch.tv/firewall154', 'Twitter: tw...                609.0
#
#       channel_view_count channel_subscriber_count channel_country  \
# 1160        7.812399e+06                    16.9K   United States
# 1161        1.278950e+06                     3.1K   United States
# 1162        6.413860e+05                    2.38K           India
# 1163        2.903736e+06                    17.2K             NaN
# 1164        6.129710e+09                    20.7M   United States
# 1165        2.848309e+09                    10.2M  United Kingdom
# 1166                 NaN                      NaN             NaN
# 1167        9.676410e+05                    7.73K         Lebanon
# 1168        5.751400e+07                    47.5K         Denmark
# 1169        8.985739e+07                     431K          Brazil
#
#      channel_creation_date             date_of_capture  is_active
# 1160   2015-10-13 00:00:00  2024-08-12 02:12:57.273002       True
# 1161   2023-10-07 00:00:00  2024-08-12 02:12:58.331821       True
# 1162   2022-09-20 00:00:00  2024-08-12 02:12:59.345039       True
# 1163   2016-07-13 00:00:00  2024-08-12 02:13:00.293596       True
# 1164   2005-06-16 00:00:00  2024-08-12 02:13:01.556649       True
# 1165   2005-10-22 00:00:00  2024-08-12 02:13:02.589071       True
# 1166                   NaN  2024-08-12 02:13:03.651637      False
# 1167   2018-07-23 00:00:00  2024-08-12 02:13:04.071459       True
# 1168   2014-09-22 00:00:00  2024-08-12 02:13:05.093544       True
# 1169   2016-05-17 00:00:00  2024-08-12 02:13:06.070695       True

# %%
# channel_video_list =[]
# channel_index = 0
# for row in channel_ids_df.itertuples():
#     print(channel_index)
#     channel_index = channel_index+1
#     if row.is_active is True:
#         video_count = 0
#         channel_set = set()
#         for video in scrapetube.get_channel(row.channel_id, limit=threshold):
#             video_count=video_count+1
#         if video_count == threshold:
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='popular')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                            
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'], view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='newest')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='oldest')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#         else:
#             videos = scrapetube.get_channel(row.channel_id)
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])

# %%
#  Iterate through the results to get the title
id = 'UCnILyLwR92FZNcAVPAOfb0A'

for video in scrapetube.get_channel(id, limit=60):
    print(video)
    # title = video['title']['runs'][0]['text']
    # if "descriptionSnippet" in video:
    #     descriptionSnippet = video['descriptionSnippet']['runs'][0]['text']
    # else:
    #     descriptionSnippet = ""
    # lengthText = video['lengthText']['simpleText']
    # thumbnail_url = video['thumbnail']['thumbnails'][0]['url']
    # # views = video['viewCountText']['simpleText']
    # # video_object_publish_date = video['publishedTimeText']['simpleText']
    # print(f"Video Title: {title}")
    # print(f"lengthText: {convert_time_to_seconds(lengthText)}")
    # print(f"descriptionSnippet: {descriptionSnippet}")
    # print(f"thumbnail_url: {thumbnail_url}")
    # print(f"views: {convert_views_to_int(views)}")
    # print(f"video_object_publish_date: {video_object_publish_date}")

url = f"https://www.youtube.com/channel/{id}"
url
# Out:
# {'videoId': 'MM_kBhMh19A', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/MM_kBhMh19A/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAeInPgA4QsjteDJcCmz1HXn-z7ng', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/MM_kBhMh19A/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAHB1t7cai08_ZRYqYpqp7cQBDfRg', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/MM_kBhMh19A/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDEPiSK--mAiORqlJ5GJkqzZqw3GA', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/MM_kBhMh19A/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDiu_SLcDbHTWEBZ30Gv84ylaDLbA', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 22-го тура Группы №2'}], 'accessibility': {'accessibilityData': {'label': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 22-го тура Группы №2 by Все о Лучших Лигах Мира 46 views 39 minutes ago 5 minutes, 9 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей двадцать второго тура Группы №2 LEON - Первенства Второй лиги ФНЛ. Дивизиона "Б" сезона 2024\n\nОказат...'}]}, 'publishedTimeText': {'simpleText': '39 minutes ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '5 minutes, 9 seconds'}}, 'simpleText': '5:09'}, 'viewCountText': {'simpleText': '46 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CPcBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrWhhVQ25JTHlMd1I5MkZaTmNBVlBBT2ZiMEGaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=MM_kBhMh19A', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'MM_kBhMh19A', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr3---sn-u0g3uxax3-pnuk.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=30cfe4061321d7d0&ip=88.244.89.50&initcwndbps=911250&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CPcBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrQNCvh5nhgPnnMA==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '46 views'}}, 'simpleText': '46 views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CPwBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CPwBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'MM_kBhMh19A', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CPwBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['MM_kBhMh19A'], 'params': 'CAQ%3D'}}, 'videoIds': ['MM_kBhMh19A']}}]}}, 'trackingParams': 'CPwBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CPsBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'offlineVideoEndpoint': {'videoId': 'MM_kBhMh19A', 'onAddCommand': {'clickTrackingParams': 'CPsBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'getDownloadActionCommand': {'videoId': 'MM_kBhMh19A', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CPsBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CPcBENwwIhMI5Lirosm_iAMVWeNCBR2 ...
# {'videoId': '-QINIXzgpcA', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/-QINIXzgpcA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLA9sJ3vAP20hbLtuCD4CJVwP-_zRw', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/-QINIXzgpcA/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCHhrw04PzA4_xgtFvyp4eT9Y7b_w', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/-QINIXzgpcA/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBXqriOgS4-vZ_pi8Mf93JOkAqFOQ', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/-QINIXzgpcA/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLADIQ4wpQOjS-eySwty5rgTYCT6GA', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 22-го тура Группы №3'}], 'accessibility': {'accessibilityData': {'label': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 22-го тура Группы №3 by Все о Лучших Лигах Мира No views 3 minutes, 53 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей двадцать второго тура Группы №3 LEON - Первенства Второй лиги ФНЛ. Дивизиона "Б" сезона 2024\n\nОказат...'}]}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '3 minutes, 53 seconds'}}, 'simpleText': '3:53'}, 'navigationEndpoint': {'clickTrackingParams': 'CPABENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrWhhVQ25JTHlMd1I5MkZaTmNBVlBBT2ZiMEGaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=-QINIXzgpcA', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': '-QINIXzgpcA', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr8---sn-u0g3uxax3-pnu6.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=f9020d217ce0a5c0&ip=88.244.89.50&initcwndbps=931250&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'upcomingEventData': {'startTime': '1726230600', 'isReminderSet': False, 'upcomingEventText': {'runs': [{'text': 'Premieres '}, {'text': 'DATE_PLACEHOLDER'}]}}, 'trackingParams': 'CPABENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrQMDLgueXpIOB-QE=', 'showActionMenu': False, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': '
 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/dq3XBO74USA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCowwdeGMlqdEahpiEkPYdlBFYE-w', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/dq3XBO74USA/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBGzDHRJhaUDHc11h0y6ZTMc8jhnA', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/dq3XBO74USA/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBGAOk3eRWN4j2thdHlHVQehiE41g', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/dq3XBO74USA/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBlA5Bf-ELoNddvWpm0oDZ5bpTojw', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'ФОНБЕТ - Кубок России по футболу 2024/2025. Путь Регионов. Обзор 3-го раунда'}], 'accessibility': {'accessibilityData': {'label': 'ФОНБЕТ - Кубок России по футболу 2024/2025. Путь Регионов. Обзор 3-го раунда by Все о Лучших Лигах Мира 3,185 views 6 days ago 7 minutes, 19 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей 3-го раунда Пути Регионов ФОНБЕТ - Кубка России по футболу 2024/2025\n\nОказать помощь жителям Курской...'}]}, 'publishedTimeText': {'simpleText': '6 days ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '7 minutes, 19 seconds'}}, 'simpleText': '7:19'}, 'viewCountText': {'simpleText': '3,185 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CM0BENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrWhhVQ25JTHlMd1I5MkZaTmNBVlBBT2ZiMEGaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=dq3XBO74USA', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'dq3XBO74USA', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr6---sn-u0g3uxax3-pnuk.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=76add704eef85120&ip=88.244.89.50&initcwndbps=911250&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CM0BENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrQKCi4ffO4PXWdg==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '3.1K views'}}, 'simpleText': '3.1K views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CNIBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CNIBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'dq3XBO74USA', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CNIBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['dq3XBO74USA'], 'params': 'CAQ%3D'}}, 'videoIds': ['dq3XBO74USA']}}]}}, 'trackingParams': 'CNIBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CNEBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'offlineVideoEndpoint': {'videoId': 'dq3XBO74USA', 'onAddCommand': {'clickTrackingParams': 'CNEBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'getDownloadActionCommand': {'videoId': 'dq3XBO74USA', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CNEBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CM0BENwwIhMI5Li ...
# {'videoId': 'PISC2brFx6Y', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/PISC2brFx6Y/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBkcvBjRpKlL1m3QyQd5YPnFKcrTA', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/PISC2brFx6Y/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDlvHGCWiYjL5OwJQyZYO8V3Zfhkg', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/PISC2brFx6Y/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCc0boc8MoMd7APRUdyq9UNLLdKXg', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/PISC2brFx6Y/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDCmOyKsuGzvS158uhBTB3Om025Cw', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 21-го тура Группы №2'}], 'accessibility': {'accessibilityData': {'label': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 21-го тура Группы №2 by Все о Лучших Лигах Мира 634 views 6 days ago 4 minutes, 49 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей двадцать первого тура Группы №2 LEON - Первенства Второй лиги ФНЛ. Дивизиона "Б" сезона 2024\n\nОказат...'}]}, 'publishedTimeText': {'simpleText': '6 days ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '4 minutes, 49 seconds'}}, 'simpleText': '4:49'}, 'viewCountText': {'simpleText': '634 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CMYBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrWhhVQ25JTHlMd1I5MkZaTmNBVlBBT2ZiMEGaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=PISC2brFx6Y', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'PISC2brFx6Y', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr5---sn-u0g3uxax3-pnud.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=3c8482d9bac5c7a6&ip=88.244.89.50&initcwndbps=913750&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CMYBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrQKaPl9ab26DCPA==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '634 views'}}, 'simpleText': '634 views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CMsBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CMsBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'PISC2brFx6Y', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CMsBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['PISC2brFx6Y'], 'params': 'CAQ%3D'}}, 'videoIds': ['PISC2brFx6Y']}}]}}, 'trackingParams': 'CMsBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CMoBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'offlineVideoEndpoint': {'videoId': 'PISC2brFx6Y', 'onAddCommand': {'clickTrackingParams': 'CMoBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'getDownloadActionCommand': {'videoId': 'PISC2brFx6Y', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CMoBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CMYBENwwIhMI5Lirosm_iAMVWeNCBR2zK ...
# {'videoId': 'YDuAhTWLOnI', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/YDuAhTWLOnI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLADWBm777WI6ILfQXfY9MlxJlwTdg', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/YDuAhTWLOnI/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CL
seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей восьмого тура Мелбет - Первенства Первой Лиги ФНЛ 2024/2025\n\nОказать помощь жителям Курской област...'}]}, 'publishedTimeText': {'simpleText': '8 days ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '8 minutes, 24 seconds'}}, 'simpleText': '8:24'}, 'viewCountText': {'simpleText': '4,644 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CLEBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrWhhVQ25JTHlMd1I5MkZaTmNBVlBBT2ZiMEGaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=KAGkLn3SrBg', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'KAGkLn3SrBg', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr1---sn-u0g3uxax3-pnu6.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=2801a42e7dd2ac18&ip=88.244.89.50&initcwndbps=931250&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CLEBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMrQJjYyu7nhemAKA==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '4.6K views'}}, 'simpleText': '4.6K views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CLYBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CLYBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'KAGkLn3SrBg', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CLYBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['KAGkLn3SrBg'], 'params': 'CAQ%3D'}}, 'videoIds': ['KAGkLn3SrBg']}}]}}, 'trackingParams': 'CLYBEP6YBBgGIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CLUBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'offlineVideoEndpoint': {'videoId': 'KAGkLn3SrBg', 'onAddCommand': {'clickTrackingParams': 'CLUBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'getDownloadActionCommand': {'videoId': 'KAGkLn3SrBg', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CLUBENGqBRgHIhMI5Lirosm_iAMVWeNCBR2zKDMr'}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CLEBENwwIhMI5Lirosm_iAMVWeNCBR2zKDMr', 'commandMetadata': {'webCommandMetadata': {' ...
# ...
# {'videoId': 'ipW8VwKbGMw', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/ipW8VwKbGMw/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBKe4tdRvTO5WhxA1vmfhGq4l9gdg', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/ipW8VwKbGMw/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCivAwm26vfyE5mHChY2Kl0cXIoHw', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/ipW8VwKbGMw/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDzjrV64fgqpELM_PoExrvaDUw3Xw', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/ipW8VwKbGMw/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBXASnTwNJCf18BG93wCnxcpFyhew', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 13-го тура Группы №3'}], 'accessibility': {'accessibilityData': {'label': 'ФНЛ. Вторая лига. Дивизион "Б". Сезон 2024. Обзор 13-го тура Группы №3 by Все о Лучших Лигах Мира 1,070 views 2 months ago 4 minutes, 15 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': 'Обзор матчей тринадцатого тура Группы №3 LEON - Первенства Второй лиги ФНЛ. Дивизиона "Б" сезона 2024\n\nПодписывай...'}]}, 'publishedTimeText': {'simpleText': '2 months ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '4 minutes, 15 seconds'}}, 'simpleText': '4:15'}, 'viewCountText': {'simpleText': '1,070 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CBAQ3DAiEwiDhfeiyb-IAxVdwEIFHYk7BidaGFVDbklMeUx3UjkyRlpOY0FWUEFPZmIwQZoBAxDyOA==', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=ipW8VwKbGMw', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'ipW8VwKbGMw', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr2---sn-u0g3uxax3-pnud.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=8a95bc57029b18cc&ip=88.244.89.50&initcwndbps=913750&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CBAQ3DAiEwiDhfeiyb-IAxVdwEIFHYk7BidAzLHslPCK78qKAQ==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '1K views'}}, 'simpleText': '1K views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CBUQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CBUQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'ipW8VwKbGMw', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CBUQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['ipW8VwKbGMw'], 'params': 'CAQ%3D'}}, 'videoIds': ['ipW8VwKbGMw']}}]}}, 'trackingParams': 'CBUQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic='}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CBQQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'offlineVideoEndpoint': {'videoId': 'ipW8VwKbGMw', 'onAddCommand': {'clickTrackingParams': 'CBQQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'getDownloadActionCommand': {'videoId': 'ipW8VwKbGMw', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CBQQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic='}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CBAQ3DAiEwiDhfeiyb-IAxVdwEI ...
# {'videoId': 'Ij09H0bXyZs', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/Ij09H0bXyZs/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4C
sn-u0g3uxax3-pnue7.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=eef49788f48c4fa5&ip=88.244.89.50&initcwndbps=960000&mt=1726218073&oweuc=&pxtags=Cg4KAnR4Egg1MTI1NzAzMg&rxtags=Cg4KAnR4Egg1MTI1NzAyOA%2CCg4KAnR4Egg1MTI1NzAyOQ%2CCg4KAnR4Egg1MTI1NzAzMA%2CCg4KAnR4Egg1MTI1NzAzMQ%2CCg4KAnR4Egg1MTI1NzAzMg'}}}}}, 'trackingParams': 'CAIQ3DAiEwiDhfeiyb-IAxVdwEIFHYk7BidApZ-xpI_xpfruAQ==', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '949 views'}}, 'simpleText': '949 views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CAcQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CAcQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': '7vSXiPSMT6U', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CAcQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['7vSXiPSMT6U'], 'params': 'CAQ%3D'}}, 'videoIds': ['7vSXiPSMT6U']}}]}}, 'trackingParams': 'CAcQ_pgEGAYiEwiDhfeiyb-IAxVdwEIFHYk7Bic='}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CAYQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'offlineVideoEndpoint': {'videoId': '7vSXiPSMT6U', 'onAddCommand': {'clickTrackingParams': 'CAYQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic=', 'getDownloadActionCommand': {'videoId': '7vSXiPSMT6U', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CAYQ0aoFGAciEwiDhfeiyb-IAxVdwEIFHYk7Bic='}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CAIQ3DAiEwiDhfeiyb-IAxVdwEIF ...
# 'https://www.youtube.com/channel/UCnILyLwR92FZNcAVPAOfb0A'

# %% [markdown]
# ## Multi Process

# %%
import os
import multiprocessing

# Using os module
num_cpu_cores = os.cpu_count()

# Using multiprocessing module
num_cpu_cores = multiprocessing.cpu_count()

print(f"Number of CPU cores: {num_cpu_cores}")

# %%
import concurrent.futures

# Function to sum a range of numbers
def sum_range(start, end):
    return sum(range(start, end + 1))

# Main function to sum 1 to 100 using parallel execution
def parallel_sum():
    ranges = [(1, 25), (26, 50), (51, 75), (76, 100)]  # Split the range into chunks
    total_sum = 0

    with concurrent.futures.ThreadPoolExecutor() as executor:
        # Submit tasks to the executor
        future_to_range = {executor.submit(sum_range, start, end): (start, end) for start, end in ranges}
        
        for future in concurrent.futures.as_completed(future_to_range):
            start, end = future_to_range[future]
            try:
                result = future.result()
                print(f"Sum of range {start} to {end} is {result}")
                total_sum += result
            except Exception as exc:
                print(f"Generated an exception: {exc}")

    return total_sum

# Execute the parallel sum
if __name__ == "__main__":
    total = parallel_sum()
    print(f"Total sum from 1 to 100 is {total}")

# %%
import requests
import random

# List of proxy servers
proxies = [
    {"http": "http://username:password@proxy1.example.com:port"},
    {"http": "http://username:password@proxy2.example.com:port"},
    {"http": "http://username:password@proxy3.example.com:port"},
    # Add more proxies as needed
]

# Your loop where each iteration uses a different proxy
for i in range(100):  # Adjust the range as needed
    proxy = random.choice(proxies)
    try:
        response = requests.get("http://your-api-endpoint.com", proxies=proxy)
        print(f"Iteration {i} Response: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error with proxy {proxy}: {e}")

    # Add any additional logic here
# Out:
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port

# %% [markdown]
# ## Validation Code

# %%
validate_df = pd.read_csv('dataset/output_dataset/from_170000_until_180000_channels_list.csv.gz', compression='gzip')
validate_df.count()
# Out:
# channel_id                  10000
# channel_name                 9704
# channel_description          9704
# channel_links                9704
# channel_video_count          9704
# channel_view_count           9704
# channel_subscriber_count     9673
# channel_country              6645
# channel_creation_date        9704
# date_of_capture             10000
# is_active                   10000
# dtype: int64
