# %% [markdown]
# # Application Project - Computational Social Science

# %% [markdown]
# ## YouTube Channels Dataset Fetch

# %%
import utils.channel_utils as cu
import utils.video_utils as vu
import utils.write_utils as wu
import utils.legacy_utils as lu
from datetime import datetime

import pandas as pd
from pytube import Channel
import scrapetube
from utils.string_utils import find_between
import ssl
from tqdm import tqdm

from IPython.display import display
ssl._create_default_https_context = ssl._create_unverified_context

# %%
channel_ids = pd.read_csv('dataset/input_dataset/channel_ids.csv.gz', compression='gzip')

# %%
channel_ids, channel_ids.count(), type(channel_ids)
# Out:
# (                        channel_id
#  0         UCYt67-MBjYF5Y8RcEAjtq1g
#  1         UCYig0vJRD03a6lkqWrbP8xg
#  2         UCOTXKyzvDOqDGDKhuScHOag
#  3         UC4bEEVSvrNu0i7FQrCMNthw
#  4         UCgia4xeNJr_VfyNYSlCmWjg
#  ...                            ...
#  15597228  UCtVOGvJJGEqpcn4lZihjlHQ
#  15597229  UC9TDkg0OnsdDG5JWmecJuOQ
#  15597230  UC0SokC74Aa8HMXZi1Bf8ksw
#  15597231  UCbE0NjJ-j34J_V8MGuApzxw
#  15597232  UCoVghWAzj3_eDZHLjWxHmrQ
#
#  [15597233 rows x 1 columns],
#  channel_id    15597232
#  dtype: int64,
#  pandas.core.frame.DataFrame)

# %%
channel_ids_as_list = channel_ids['channel_id'].to_list()

# %% [markdown]
# ## Channel Attributes

# %% [markdown]
# ### Example for one youtube channel

# %%
#TEST
index = 79139
first_channel_id = channel_ids_as_list[index]
channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
channel_object = Channel(channel_url)
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2009, 2, 3, 0, 0)

# %%
#Get first 1 id from the id list
first_channel_id = channel_ids_as_list[79132]

#channel with most video uploads
# first_channel_id = "UCPF-oYb2-xN5FbCXy0167Gg"

# %%
# channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
channel_url = "https://www.youtube.com/channel/UCBR8-60-B28hp2BmDPdntcQ"
# channel_url = "https://www.youtube.com/channel/UCZvJUIAiQROopthP-KTtW7g"
# channel_url = "https://www.youtube.com/channel/UCasyWKltNuQ3bGn29Iep7TA"
channel_url
# Out:
# 'https://www.youtube.com/channel/UCBR8-60-B28hp2BmDPdntcQ'

# %%
channel_object = Channel(channel_url)

# %%
#Channel ID
channel_id = channel_object.channel_id
# channel_object.about_html

# %%
#Channel name
channel_object.channel_name
# Out:
# 'YouTube'

# %%
#Channel Description
channel_about_html = str(channel_object.about_html)
channel_description = find_between(channel_about_html, 'name="description" content="', '"><meta name="keywords"')
channel_description
# Out:
# 'YouTube&#39;s Official Channel helps you discover what&#39;s new &amp; trending globally. Watch must-see videos, from music to culture to Internet phenomena'

# %%
with open("output_test.txt", "w") as file:
    # Write the string to the file
    file.write(channel_about_html)

# %%
#Channel Links
import json
channel_about_html = str(channel_object.about_html)
channels_links_as_string = find_between(channel_about_html, ',"links":', ',"displayCanonicalChannelUrl":')
try:
    channels_links_as_list = json.loads(channels_links_as_string)
except:
    channels_links_as_list = {}
channels_links_per_channel = []
for channel in channels_links_as_list:
    print(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")
    channels_links_per_channel.append(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")
# Out:
# The best of YouTube every day: youtube.com/user/youtube?sub_confirmation=1
# Instagram: instagram.com/youtube
# Twitter: twitter.com/youtube
# Facebook: facebook.com/youtube
# YouTube Culture & Trends: youtube.com/trends

# %%
#Channel yt api key might be important
channel_object.yt_api_key
# Out:
# 'AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8'

# %%
#Channel Subscribers
channel_about_html = str(channel_object.about_html)
channel_subscriber = find_between(channel_about_html, '"subscriberCountText":"', ' subscribers')
channel_subscriber
# Out:
# '41.2M'

# %%
#Channel Video Count
channel_about_html = str(channel_object.about_html)
channel_video_count = int(find_between(channel_about_html, ',"videoCountText":"', ' videos",').replace(',' , ''))
channel_video_count
# Out:
# 764

# %%
#Channel View Count
channel_about_html = str(channel_object.about_html)
channel_view_count = int(find_between(channel_about_html, ',"viewCountText":"', ' views",').replace(',' , ''))
channel_view_count
# Out:
# 2742754363

# %%
#Channel creation Date
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[230], line 3
#       1 #Channel creation Date
#       2 channel_about_html = str(channel_object.about_html)
# ----> 3 channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
#       4 channel_creation_date
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '' does not match format '%b %d %Y'

# %%
# Open the file in read mode
with open('output.txt', 'r') as file:
    # Read the entire file into a variable
    content = file.read()

# Now you can use the 'content' variable
temp = content

# %%
#Channel creation Date
channel_about_html = str(temp)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[173], line 3
#       1 #Channel creation Date
#       2 channel_about_html = str(temp)
# ----> 3 channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
#       4 channel_creation_date
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '' does not match format '%b %d %Y'

# %%
#Channel Country
channel_about_html = str(channel_object.about_html)
channel_country = find_between(channel_about_html, '"country":"', '","')
channel_country
# Out:
# 'South Korea'

# %%
channel_object.channel_id, channel_object.channel_name, channel_description, channels_links_per_channel, channel_subscriber, videos_list_per_channel

# %% [markdown]
# #### Video Attributes

# %%
from pytube import YouTube

# %%
vide_url = "https://www.youtube.com/watch?v=NIq14KtuVaM"

# %%
video_object = YouTube(vide_url)

# %%
video_object.title, video_object.author, video_object.publish_date, video_object.thumbnail_url, video_object.length

# %% [markdown]
# ## ScrapeTube - Youtube Channel- Video By Sampling

# %%
channel_ids = channel_ids_as_list[0:10]

# %%
hundred_channels_df = pd.read_csv('dataset/output_dataset/from_70000_until_80000_channels_list.csv')
hundred_channels_df.columns, hundred_channels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   channel_id                9000 non-null   object
#  1   channel_name              8576 non-null   object
#  2   channel_description       8576 non-null   object
#  3   channel_links             8577 non-null   object
#  4   channel_video_count       8577 non-null   float64
#  5   channel_view_count        8577 non-null   float64
#  6   channel_subscriber_count  8367 non-null   object
#  7   channel_country           5312 non-null   object
#  8   channel_creation_date     8577 non-null   object
#  9   date_of_capture           9000 non-null   object
#  10  is_active                 9000 non-null   bool
# dtypes: bool(1), float64(2), object(8)
# memory usage: 712.0+ KB
# (Index(['channel_id', 'channel_name', 'channel_description', 'channel_links',
#         'channel_video_count', 'channel_view_count', 'channel_subscriber_count',
#         'channel_country', 'channel_creation_date', 'date_of_capture',
#         'is_active'],
#        dtype='object'),
#  None)

# %%
filtered_df = hundred_channels_df.loc[hundred_channels_df['channel_video_count'] == 0]
print(filtered_df)
# Out:
#                     channel_id                channel_name  \
# 48    UCKh3RR_76axFObQmBtvMEbw                         정명자
# 74    UC4ipJz3To0EX0e18_IZbDWA                   nanas yey
# 97    UCdGKJ7bxgwJXStoTZR9MmCw                         피미믹
# 106   UCz9hANw-esy6ENb4bUIg6Jg                         레이쿤
# 116   UCdV_6jS2hL3XK6pHwptTHkA                    Jenny 제니
# ...                        ...                         ...
# 8614  UCHk1KHr66HRqXfbNlYKyROw                        어쭈뀨리
# 8617  UCSMZPYKUC1WXl5KseRBI9yA  Worldwide Watchlist Movies
# 8688  UCRBbjIerVxyqjDJe6TJBM8A                      Kawaii
# 8863  UCJums3DCYEWmo5c5Ch73lVw                   MX Remix
# 8941  UClxDr7TYXoX5Of8IMDP87Fg                      Dmedia
#
#                                     channel_description  \
# 48    Share your videos with friends, family, and th...
# 74    Share your videos with friends, family, and th...
# 97               당신의 관심이 나를 진화시킨다1차 진화 - 구독자 100명 (미완료)
# 106                          영화,드라마,애니 나만의 시선으로 해석하는 채널
# 116                                               핫도그냐미
# ...                                                 ...
# 8614  Share your videos with friends, family, and th...
# 8617  Welcome To WWW Movies!Giving you only the best...
# 8688                                      Y la keso Xdd
# 8863  Share your videos with friends, family, and th...
# 8941                 Bienvenue sur notre chaîne Dmedia
#
#                                           channel_links  channel_video_count  \
# 48                                                   []                  0.0
# 74                                                   []                  0.0
# 97     ['후원 (투네이션): toon.at/donate/638038284464827950']                  0.0
# 106                                                  []                  0.0
# 116                                                  []                  0.0
# ...                                                 ...                  ...
# 8614                                                 []                  0.0
# 8617                                                 []                  0.0
# 8688                                                 []                  0.0
# 8863  ['Facebook: facebook.com/profile.php?id=100058...                  0.0
# 8941                                                 []                  0.0
#
#       channel_view_count channel_subscriber_count channel_country  \
# 48                   0.0                        7             NaN
# 74                   9.0                      NaN             NaN
# 97                   2.0                       34     South Korea
# 106                 22.0                      NaN             NaN
# 116                 13.0                      NaN             NaN
# ...                  ...                      ...             ...
# 8614                 0.0                    1.06K             NaN
# 8617                 0.0                    1.12M        Slovenia
# 8688                14.0                       31             NaN
# 8863                 0.0                    20.1K         Vietnam
# 8941            180218.0                     148K          France
#
#      channel_creation_date             date_of_capture  is_active
# 48     2023-05-13 00:00:00  2024-08-19 20:27:12.878438       True
# 74     2019-06-02 00:00:00  2024-08-19 20:27:38.734843       True
# 97     2014-06-14 00:00:00  2024-08-19 20:28:00.477291       True
# 106    2018-06-16 00:00:00  2024-08-19 20:28:08.434556       True
# 116    2022-04-02 00:00:00  2024-08-19 20:28:16.221223       True
# ...                    ...                         ...        ...
# 8614   2020-07-15 00:00:00  2024-08-19 22:28:39.090332       True
# 8617   2023-06-19 00:00:00  2024-08-19 22:28:41.065847       True
# 8688   2017-01-28 00:00:00  2024-08-19 22:29:34.591775       True
# 8863   2022-12-22 00:00:00  2024-08-19 22:32:01.646437       True
# 8941   2021-05-07 00:00:00  2024-08-19 22:33:05.769008       True
#
# [254 rows x 11 columns]

# %%
temp_df = pd.read_csv('dataset/output_dataset/from_0_until_1000_channels_list.csv.gz', compression='gzip')
channel_ids_df = temp_df[0:10]
len(channel_ids_df["channel_id"].unique())
# Out:
# 10

# %%
# Iterate through the results to get the title
for video in scrapetube.get_channel("UCgia4xeNJr_VfyNYSlCmWjg", limit=120):
    print(f"{video}")
    print()
# Out:
# {'videoId': 'wLvileX_LvE', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/wLvileX_LvE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGFkgZSgTMA8=&rs=AOn4CLAJulPqGJDul3LFEzsRhEOp71500Q', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/wLvileX_LvE/hqdefault.jpg?sqp=-oaymwE1CMQBEG5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGFkgZSgTMA8=&rs=AOn4CLCCke1geMps-6kCW93hGILdc3LHSg', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/wLvileX_LvE/hqdefault.jpg?sqp=-oaymwE2CPYBEIoBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARhZIGUoEzAP&rs=AOn4CLAdHNfmoPxVVoadgeK-9pVU4cWYlQ', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/wLvileX_LvE/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARhZIGUoEzAP&rs=AOn4CLC0x68UtFVAIp1reVXKr8uiQe0kNA', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'FLUIR - SOL MARGUELICHE'}], 'accessibility': {'accessibilityData': {'label': 'FLUIR - SOL MARGUELICHE by Sol Margueliche No views 3 minutes, 44 seconds'}}}, 'descriptionSnippet': {'runs': [{'text': '#reggaeargentino #reggae  #reggaemusic \n\nEn un año marcado por desencuentros laborales, emocionales e institucionales, y por la ausencia de políticas que apoyen el desarrollo profesional,...'}]}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '3 minutes, 44 seconds'}}, 'simpleText': '3:44'}, 'navigationEndpoint': {'clickTrackingParams': 'COQBENwwIhMIqfCUyKWWiAMVWFp6BR2k_gnhWhhVQ2dpYTR4ZU5Kcl9WZnlOWVNsQ21XameaAQMQ8jg=', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=wLvileX_LvE', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'wLvileX_LvE', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr5---sn-u0g3uxax3-pnud.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=c0bbe295e5ff2ef1&ip=88.244.89.50&initcwndbps=910000&mt=1724799652&oweuc='}}}}}, 'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'OFFICIAL_ARTIST_BADGE'}, 'style': 'BADGE_STYLE_TYPE_VERIFIED_ARTIST', 'tooltip': 'Official Artist Channel', 'trackingParams': 'COQBENwwIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'accessibilityData': {'label': 'Official Artist Channel'}}}], 'upcomingEventData': {'startTime': '1727474400', 'isReminderSet': False, 'upcomingEventText': {'runs': [{'text': 'Premieres '}, {'text': 'DATE_PLACEHOLDER'}]}}, 'trackingParams': 'COQBENwwIhMIqfCUyKWWiAMVWFp6BR2k_gnhQPHd_K_e0vjdwAE=', 'showActionMenu': False, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'COkBEP6YBBgGIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'COkBEP6YBBgGIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'wLvileX_LvE', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'COkBEP6YBBgGIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['wLvileX_LvE'], 'params': 'CAQ%3D'}}, 'videoIds': ['wLvileX_LvE']}}]}}, 'trackingParams': 'COkBEP6YBBgGIhMIqfCUyKWWiAMVWFp6BR2k_gnh'}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'COgBENGqBRgHIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'offlineVideoEndpoint': {'videoId': 'wLvileX_LvE', 'onAddCommand': {'clickTrackingParams': 'COgBENGqBRgHIhMIqfCUyKWWiAMVWFp6BR2k_gnh', 'getDownloadActionCommand': {'videoId': 'wLvileX_LvE', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'COgBENGqBRgHIhMIqfCUyKWWiAMVWFp6BR2k_gnh'}} ...
#
# {'videoId': 'f-1RiElB7OM', 'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/f-1RiElB7OM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGEEgZChlMA8=&rs=AOn4CLCVXxLCr9Tjy22dnxSctd-ydWeo8g', 'width': 168, 'height': 94}, {'url': 'https://i.ytimg.com/vi/f-1RiElB7OM/hqdefault.jpg?sqp=-oaymwE1CMQBEG5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABAB
IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDIviaY93RkQZoTW3uTEGm8lU8sBg', 'width': 196, 'height': 110}, {'url': 'https://i.ytimg.com/vi/SdQSHXBRULk/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDmspsx3SMxplG3xBkyeNlSfXS44g', 'width': 246, 'height': 138}, {'url': 'https://i.ytimg.com/vi/SdQSHXBRULk/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD3ecPY991JDCR87u7x7gXEKzTvgw', 'width': 336, 'height': 188}]}, 'title': {'runs': [{'text': 'Lunáticas en la estación'}], 'accessibility': {'accessibilityData': {'label': 'Lunáticas en la estación by Sol Margueliche 91 views 7 years ago 2 minutes'}}}, 'descriptionSnippet': {'runs': [{'text': 'Facebook: Muchas Sol Margueliche\n\nTambién podes escuchar:\nEnClaveReggae -2016-\n\nhttps://web.facebook.com/EnClaveReggae/?fref=ts'}]}, 'publishedTimeText': {'simpleText': '7 years ago'}, 'lengthText': {'accessibility': {'accessibilityData': {'label': '2 minutes'}}, 'simpleText': '2:00'}, 'viewCountText': {'simpleText': '91 views'}, 'navigationEndpoint': {'clickTrackingParams': 'CC4Q3DAiEwip8JTIpZaIAxVYWnoFHaT-CeFaGFVDZ2lhNHhlTkpyX1ZmeU5ZU2xDbVdqZ5oBAxDyOA==', 'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=SdQSHXBRULk', 'webPageType': 'WEB_PAGE_TYPE_WATCH', 'rootVe': 3832}}, 'watchEndpoint': {'videoId': 'SdQSHXBRULk', 'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr5---sn-u0g3uxax3-pnuk.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=49d4121d705150b9&ip=88.244.89.50&initcwndbps=1112500&mt=1724799652&oweuc='}}}}}, 'ownerBadges': [{'metadataBadgeRenderer': {'icon': {'iconType': 'OFFICIAL_ARTIST_BADGE'}, 'style': 'BADGE_STYLE_TYPE_VERIFIED_ARTIST', 'tooltip': 'Official Artist Channel', 'trackingParams': 'CC4Q3DAiEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'accessibilityData': {'label': 'Official Artist Channel'}}}], 'trackingParams': 'CC4Q3DAiEwip8JTIpZaIAxVYWnoFHaT-CeFAuaHFgtfDhOpJ', 'showActionMenu': False, 'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '91 views'}}, 'simpleText': '91 views'}, 'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]}, 'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'}, 'serviceEndpoint': {'clickTrackingParams': 'CDMQ_pgEGAYiEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True}}, 'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL', 'actions': [{'clickTrackingParams': 'CDMQ_pgEGAYiEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'addToPlaylistCommand': {'openMiniplayer': True, 'videoId': 'SdQSHXBRULk', 'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE', 'onCreateListCommand': {'clickTrackingParams': 'CDMQ_pgEGAYiEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'commandMetadata': {'webCommandMetadata': {'sendPost': True, 'apiUrl': '/youtubei/v1/playlist/create'}}, 'createPlaylistServiceEndpoint': {'videoIds': ['SdQSHXBRULk'], 'params': 'CAQ%3D'}}, 'videoIds': ['SdQSHXBRULk']}}]}}, 'trackingParams': 'CDMQ_pgEGAYiEwip8JTIpZaIAxVYWnoFHaT-CeE='}}, {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CDIQ0aoFGAciEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'offlineVideoEndpoint': {'videoId': 'SdQSHXBRULk', 'onAddCommand': {'clickTrackingParams': 'CDIQ0aoFGAciEwip8JTIpZaIAxVYWnoFHaT-CeE=', 'getDownloadActionCommand': {'videoId': 'SdQSHXBRULk', 'params': 'CAIQAA%3D%3D'}}}}, 'trackingParams': 'CDIQ0aoFGAciEwip8JTIpZaIAxVYWnoFHaT-CeE='}}, {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]}, 'icon': {'iconType': 'SHARE'}, 'serviceEndpoint': {'clickTrackingParams': 'CC4Q3DAiEwip8JT ...

# %%
def convert_time_to_seconds(time_string):
    # Split the time string by ':'
    time_parts = list(map(int, time_string.split(':')))
    
    # Initialize total_seconds
    total_seconds = 0

    # If the format is hh:mm:ss
    if len(time_parts) == 3:
        hours, minutes, seconds = time_parts
        total_seconds = (hours * 3600) + (minutes * 60) + seconds

    # If the format is mm:ss
    elif len(time_parts) == 2:
        minutes, seconds = time_parts
        total_seconds = (minutes * 60) + seconds

    # If the format is just seconds
    elif len(time_parts) == 1:
        total_seconds = time_parts[0]

    return total_seconds

# Example usage
time_strings = ["96:00:00", "12:00", "25"]

for time_string in time_strings:
    seconds = convert_time_to_seconds(time_string)
    print(f"{time_string} -> {seconds} seconds")


# Example usage
time_string = "96:00:00"
seconds = convert_time_to_seconds(time_string)
print(f"{time_string} -> {seconds} seconds")


def convert_views_to_int(view_string):
    # Remove non-numeric characters
    numeric_string = ''.join(filter(str.isdigit, view_string))
    # Convert the numeric string to an integer
    return int(numeric_string)

# Example usage
view_string = "15,218 views"
views = convert_views_to_int(view_string)
print(f"{view_string} -> {views} views")
# Out:
# 96:00:00 -> 345600 seconds
# 12:00 -> 720 seconds
# 25 -> 25 seconds
# 96:00:00 -> 345600 seconds
# 15,218 views -> 15218 views

# %%
trial_df = pd.read_csv('dataset/output_dataset/from_2000_until_10000_channels_list.csv.gz', compression='gzip')
channel_ids_df = trial_df[860:870]
threshold = 120

# %%
channel_video_list =[]
channel_index = 0
for row in channel_ids_df.itertuples():
    print(channel_index)
    channel_index = channel_index+1
    if row.is_active is True:
        video_count = 0
        channel_set = set()
        for video in scrapetube.get_channel(row.channel_id, limit=threshold):
            video_count=video_count+1
        if video_count == threshold:
            videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='popular', content_type = "videos")
            for video in videos:
                current_time = datetime.now()
                if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                    
                    if "descriptionSnippet" in video:
                        video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
                    else:
                        video_description = ""
                        
                    if "upcomingEventData" in video:
                        view_count = None
                        publish_date = None
                    elif video['viewCountText']['simpleText']=="No views":
                        view_count = 0
                        publish_date = video['publishedTimeText']['simpleText']
                    else:
                        view_count = convert_views_to_int(video['viewCountText']['simpleText'])
                        publish_date = video['publishedTimeText']['simpleText']
                        
                    if 'title' in video:
                        video_title = video['title']['runs'][0]['text']
                    else:
                        video_title = None
                        
                    channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'], view_count, publish_date, current_time])
                    channel_set.add(video['videoId'])
            videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='newest', content_type = "videos")
            for video in videos:
                current_time = datetime.now()
                if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                    
                    if "descriptionSnippet" in video:
                        video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
                    else:
                        video_description = ""
                        
                    if "upcomingEventData" in video:
                        view_count = None
                        publish_date = None
                    elif video['viewCountText']['simpleText']=="No views":
                        view_count = 0
                        publish_date = video['publishedTimeText']['simpleText']
                    else:
                        view_count = convert_views_to_int(video['viewCountText']['simpleText'])
                        publish_date = video['publishedTimeText']['simpleText']
                    
                    if 'title' in video:
                        video_title = video['title']['runs'][0]['text']
                    else:
                        video_title = None
                        
                    channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
                    channel_set.add(video['videoId'])
            videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='oldest', content_type = "videos")
            for video in videos:
                current_time = datetime.now()
                if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                    
                    if "descriptionSnippet" in video:
                        video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
                    else:
                        video_description = ""
                        
                    if "upcomingEventData" in video:
                        view_count = None
                        publish_date = None
                    elif video['viewCountText']['simpleText']=="No views":
                        view_count = 0
                        publish_date = video['publishedTimeText']['simpleText']
                    else:
                        view_count = convert_views_to_int(video['viewCountText']['simpleText'])
                        publish_date = video['publishedTimeText']['simpleText']
                    
                    if 'title' in video:
                        video_title = video['title']['runs'][0]['text']
                    else:
                        video_title = None
                        
                    channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
                    channel_set.add(video['videoId'])
        else:
            videos = scrapetube.get_channel(row.channel_id, content_type = "videos")
            for video in videos:
                current_time = datetime.now()
                if video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                    
                    if "descriptionSnippet" in video:
                        video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
                    else:
                        video_description = ""
                        
                    if "upcomingEventData" in video:
                        view_count = None
                        publish_date = None
                    elif video['viewCountText']['simpleText']=="No views":
                        view_count = 0
                        publish_date = video['publishedTimeText']['simpleText']
                    else:
                        view_count = convert_views_to_int(video['viewCountText']['simpleText'])
                        publish_date = video['publishedTimeText']['simpleText']
                    
                    if 'title' in video:
                        video_title = video['title']['runs'][0]['text']
                    else:
                        video_title = None
                        
                    channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
# Out:
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 115
#     112     publish_date = video['publishedTimeText']['simpleText']
#     114 if 'title' in video:
# --> 115     video_title = video['title']['runs'][0]['text']
#     116 else:
#     117     video_title = None
#
# KeyError: 'runs'

# %%
video
# Out:
# {'videoId': 'Lp4tHc67qoc',
#  'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/Lp4tHc67qoc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHOBYACuAiKAgwIABABGGUgVShDMA8=&rs=AOn4CLBCP0X4Ww5lLYbAtRw2GySt-ZfWsw',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/Lp4tHc67qoc/hqdefault.jpg?sqp=-oaymwE1CMQBEG5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHOBYACuAiKAgwIABABGGUgVShDMA8=&rs=AOn4CLAEmkiwMzhjqDxifpIkLg8SPUDtEQ',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/Lp4tHc67qoc/hqdefault.jpg?sqp=-oaymwE2CPYBEIoBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgBzgWAArgIigIMCAAQARhlIFUoQzAP&rs=AOn4CLAiSth-ny8xJkKs-LQxv8IJRsG8fQ',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/Lp4tHc67qoc/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFXyq4qpAygIARUAAIhCGAFwAcABBvABAfgBzgWAArgIigIMCAAQARhlIFUoQzAP&rs=AOn4CLAqxPQp66x_HP6K3bOPQHUGEGt97w',
#     'width': 336,
#     'height': 188}]},
#  'title': {'accessibility': {'accessibilityData': {'label': 'Dinosaurus but UFC avegers#shorts  #dinosaur by Cartoon Simple 270 views 1 year ago 26 seconds'}},
#   'simpleText': 'Dinosaurus but UFC avegers#shorts  #dinosaur'},
#  'descriptionSnippet': {'runs': [{'text': 'Dinosaur but UFC#shorts \n\n\n\ntag\nDinosaur but UFC ,Shorts viral ,dinosaurus T-rex ,video Shorts dinosaur ,video Shorts T-rek ,dinosaur word ,Dinosaur T-rek Jurassic word ,video T-rek Jurassic...'}]},
#  'longBylineText': {'runs': [{'text': 'Cartoon Simple',
#     'navigationEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#      'commandMetadata': {'webCommandMetadata': {'url': '/@CartoonSimple_dz',
#        'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#        'rootVe': 3611,
#        'apiUrl': '/youtubei/v1/browse'}},
#      'browseEndpoint': {'browseId': 'UC1KlPtZBlxg36q0yG_rHMgw',
#       'canonicalBaseUrl': '/@CartoonSimple_dz'}}}]},
#  'publishedTimeText': {'simpleText': '1 year ago'},
#  'lengthText': {'accessibility': {'accessibilityData': {'label': '26 seconds'}},
#   'simpleText': '0:26'},
#  'viewCountText': {'simpleText': '270 views'},
#  'navigationEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlTIGZy1oaWdoWhhVQzFLbFB0WkJseGczNnEweUdfckhNZ3eaAQYQ8jgYzAGqARhVVTFLbFB0WkJseGczNnEweUdfckhNZ3c=',
#   'commandMetadata': {'webCommandMetadata': {'url': '/watch?v=Lp4tHc67qoc',
#     'webPageType': 'WEB_PAGE_TYPE_WATCH',
#     'rootVe': 3832}},
#   'watchEndpoint': {'videoId': 'Lp4tHc67qoc',
#    'watchEndpointSupportedOnesieConfig': {'html5PlaybackOnesieConfig': {'commonConfig': {'url': 'https://rr4---sn-u0g3uxax3-pnue7.googlevideo.com/initplayback?source=youtube&oeis=1&c=WEB&oad=3200&ovd=3200&oaad=11000&oavd=11000&ocs=700&oewis=1&oputc=1&ofpcc=1&msp=1&odepv=1&id=2e9e2d1dcebbaa87&ip=88.244.89.50&initcwndbps=1011250&mt=1725137595&oweuc='}}}}},
#  'ownerText': {'runs': [{'text': 'Cartoon Simple',
#     'navigationEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#      'commandMetadata': {'webCommandMetadata': {'url': '/@CartoonSimple_dz',
#        'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#        'rootVe': 3611,
#        'apiUrl': '/youtubei/v1/browse'}},
#      'browseEndpoint': {'browseId': 'UC1KlPtZBlxg36q0yG_rHMgw',
#       'canonicalBaseUrl': '/@CartoonSimple_dz'}}}]},
#  'shortBylineText': {'runs': [{'text': 'Cartoon Simple',
#     'navigationEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#      'commandMetadata': {'webCommandMetadata': {'url': '/@CartoonSimple_dz',
#        'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#        'rootVe': 3611,
#        'apiUrl': '/youtubei/v1/browse'}},
#      'browseEndpoint': {'browseId': 'UC1KlPtZBlxg36q0yG_rHMgw',
#       'canonicalBaseUrl': '/@CartoonSimple_dz'}}}]},
#  'trackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlUCH1e713KOLzy6qARhVVTFLbFB0WkJseGczNnEweUdfckhNZ3c=',
#  'showActionMenu': False,
#  'shortViewCountText': {'accessibility': {'accessibilityData': {'label': '270 views'}},
#   'simpleText': '270 views'},
#  'menu': {'menuRenderer': {'items': [{'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Add to queue'}]},
#       'icon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#       'serviceEndpoint': {'clickTrackingParams': 'CCYQ_pgEGAgiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#        'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#        'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#         'actions': [{'clickTrackingParams': 'CCYQ_pgEGAgiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#           'addToPlaylistCommand': {'openMiniplayer': True,
#            'videoId': 'Lp4tHc67qoc',
#            'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#            'onCreateListCommand': {'clickTrackingParams': 'CCYQ_pgEGAgiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#             'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#               'apiUrl': '/youtubei/v1/playlist/create'}},
#             'createPlaylistServiceEndpoint': {'videoIds': ['Lp4tHc67qoc'],
#              'params': 'CAQ%3D'}},
#            'videoIds': ['Lp4tHc67qoc']}}]}},
#       'trackingParams': 'CCYQ_pgEGAgiEwjUnoaskKCIAxVgwEIFHf41LZU='}},
#     {'menuServiceItemDownloadRenderer': {'serviceEndpoint': {'clickTrackingParams': 'CCUQ0aoFGAkiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#        'offlineVideoEndpoint': {'videoId': 'Lp4tHc67qoc',
#         'onAddCommand': {'clickTrackingParams': 'CCUQ0aoFGAkiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#          'getDownloadActionCommand': {'videoId': 'Lp4tHc67qoc',
#           'params': 'CAIQAA%3D%3D'}}}},
#       'trackingParams': 'CCUQ0aoFGAkiEwjUnoaskKCIAxVgwEIFHf41LZU='}},
#     {'menuServiceItemRenderer': {'text': {'runs': [{'text': 'Share'}]},
#       'icon': {'iconType': 'SHARE'},
#       'serviceEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#        'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#          'apiUrl': '/youtubei/v1/share/get_share_panel'}},
#        'shareEntityServiceEndpoint': {'serializedShareEntity': 'CgtMcDR0SGM2N3FvYw%3D%3D',
#         'commands': [{'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#           'openPopupAction': {'popup': {'unifiedSharePanelRenderer': {'trackingParams': 'CCQQjmIiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#              'showLoadingSpinner': True}},
#            'popupType': 'DIALOG',
#            'beReused': True}}]}},
#       'trackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#       'hasSeparator': True}}],
#    'trackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#    'accessibility': {'accessibilityData': {'label': 'Action menu'}}}},
#  'channelThumbnailSupportedRenderers': {'channelThumbnailWithLinkRenderer': {'thumbnail': {'thumbnails': [{'url': 'https://yt3.googleusercontent.com/6SEZRTO0GzP9YTu3Vj_187OXzOs2PY-EQ9ItLArZvVVN2BHcdMmBLwMyE-zCr7w0e-HVjU1Wkw=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}]},
#    'navigationEndpoint': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#     'commandMetadata': {'webCommandMetadata': {'url': '/@CartoonSimple_dz',
#       'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#       'rootVe': 3611,
#       'apiUrl': '/youtubei/v1/browse'}},
#     'browseEndpoint': {'browseId': 'UC1KlPtZBlxg36q0yG_rHMgw',
#      'canonicalBaseUrl': '/@CartoonSimple_dz'}},
#    'accessibility': {'accessibilityData': {'label': 'Go to channel'}}}},
#  'thumbnailOverlays': [{'thumbnailOverlayTimeStatusRenderer': {'text': {'accessibility': {'accessibilityData': {'label': '26 seconds'}},
#      'simpleText': '0:26'},
#     'style': 'DEFAULT'}},
#   {'thumbnailOverlayToggleButtonRenderer': {'isToggled': False,
#     'untoggledIcon': {'iconType': 'WATCH_LATER'},
#     'toggledIcon': {'iconType': 'CHECK'},
#     'untoggledTooltip': 'Watch later',
#     'toggledTooltip': 'Added',
#     'untoggledServiceEndpoint': {'clickTrackingParams': 'CCMQ-ecDGAEiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#      'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#        'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#      'playlistEditEndpoint': {'playlistId': 'WL',
#       'actions': [{'addedVideoId': 'Lp4tHc67qoc',
#         'action': 'ACTION_ADD_VIDEO'}]}},
#     'toggledServiceEndpoint': {'clickTrackingParams': 'CCMQ-ecDGAEiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#      'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#        'apiUrl': '/youtubei/v1/browse/edit_playlist'}},
#      'playlistEditEndpoint': {'playlistId': 'WL',
#       'actions': [{'action': 'ACTION_REMOVE_VIDEO_BY_VIDEO_ID',
#         'removedVideoId': 'Lp4tHc67qoc'}]}},
#     'untoggledAccessibility': {'accessibilityData': {'label': 'Watch later'}},
#     'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#     'trackingParams': 'CCMQ-ecDGAEiEwjUnoaskKCIAxVgwEIFHf41LZU='}},
#   {'thumbnailOverlayToggleButtonRenderer': {'untoggledIcon': {'iconType': 'ADD_TO_QUEUE_TAIL'},
#     'toggledIcon': {'iconType': 'PLAYLIST_ADD_CHECK'},
#     'untoggledTooltip': 'Add to queue',
#     'toggledTooltip': 'Added',
#     'untoggledServiceEndpoint': {'clickTrackingParams': 'CCIQx-wEGAIiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#      'commandMetadata': {'webCommandMetadata': {'sendPost': True}},
#      'signalServiceEndpoint': {'signal': 'CLIENT_SIGNAL',
#       'actions': [{'clickTrackingParams': 'CCIQx-wEGAIiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#         'addToPlaylistCommand': {'openMiniplayer': True,
#          'videoId': 'Lp4tHc67qoc',
#          'listType': 'PLAYLIST_EDIT_LIST_TYPE_QUEUE',
#          'onCreateListCommand': {'clickTrackingParams': 'CCIQx-wEGAIiEwjUnoaskKCIAxVgwEIFHf41LZU=',
#           'commandMetadata': {'webCommandMetadata': {'sendPost': True,
#             'apiUrl': '/youtubei/v1/playlist/create'}},
#           'createPlaylistServiceEndpoint': {'videoIds': ['Lp4tHc67qoc'],
#            'params': 'CAQ%3D'}},
#          'videoIds': ['Lp4tHc67qoc']}}]}},
#     'untoggledAccessibility': {'accessibilityData': {'label': 'Add to queue'}},
#     'toggledAccessibility': {'accessibilityData': {'label': 'Added'}},
#     'trackingParams': 'CCIQx-wEGAIiEwjUnoaskKCIAxVgwEIFHf41LZU='}},
#   {'thumbnailOverlayNowPlayingRenderer': {'text': {'runs': [{'text': 'Now playing'}]}}}],
#  'richThumbnail': {'movingThumbnailRenderer': {'movingThumbnailDetails': {'thumbnails': [{'url': 'https://i.ytimg.com/an_webp/Lp4tHc67qoc/mqdefault_6s.webp?du=3000&sqp=CPaEzrYG&rs=AOn4CLA7Zba6GxybErAdMaDpDJLvSSXkGw',
#       'width': 320,
#       'height': 180}],
#     'logAsMovingThumbnail': True},
#    'enableHoveredLogging': True,
#    'enableOverlay': True}},
#  'avatar': {'decoratedAvatarViewModel': {'avatar': {'avatarViewModel': {'image': {'sources': [{'url': 'https://yt3.googleusercontent.com/6SEZRTO0GzP9YTu3Vj_187OXzOs2PY-EQ9ItLArZvVVN2BHcdMmBLwMyE-zCr7w0e-HVjU1Wkw=s68-c-k-c0x00ffffff-no-rj',
#         'width': 68,
#         'height': 68}]},
#      'avatarImageSize': 'AVATAR_SIZE_M'}},
#    'a11yLabel': 'Go to channel',
#    'rendererContext': {'commandContext': {'onTap': {'innertubeCommand': {'clickTrackingParams': 'CCEQ3DAYACITCNSehqyQoIgDFWDAQgUd_jUtlQ==',
#        'commandMetadata': {'webCommandMetadata': {'url': '/@CartoonSimple_dz',
#          'webPageType': 'WEB_PAGE_TYPE_CHANNEL',
#          'rootVe': 3611,
#          'apiUrl': '/youtubei/v1/browse'}},
#        'browseEndpoint': {'browseId': 'UC1KlPtZBlxg36q0yG_rHMgw',
#         'canonicalBaseUrl': '/@CartoonSimple_dz'}}}}}}}}

# %%
video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]
# Out:
# 'LIVE'

# %%
channel_video_list
# Out:
# [['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'TvfnJvmolrQ',
#   'No Force Remix - Fugazis x Jeyson Feat. @ValentinoGRM x @ElZetaPty x @Andiexpa (Oficial Visualizer)',
#   326,
#   'PRODUCCIÓN MUSICAL | YOW PRADO | SMILE BEATSVISUAL | DanielptyMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info...',
#   'https://i.ytimg.com/vi/TvfnJvmolrQ/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gEyhjMA8=&rs=AOn4CLAQY9Lx5rdGarrIMDVJxwPloNvyGg',
#   55184,
#   '3 weeks ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412462)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'ruURmMo6gQA',
#   'Muñequita - JEYSON x El Tiex (Audio Oficial)',
#   171,
#   '#Muñequita #JeysonPRODUCCIÓN MUSICAL | YOW PRADOVISUAL | DanielptyMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email:...',
#   'https://i.ytimg.com/vi/ruURmMo6gQA/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGG0gEyh_MA8=&rs=AOn4CLBrKqQTSPcmTWk5SbRuDcIL6N3evw',
#   31700,
#   '3 weeks ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412507)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'E7PjJTBuyL4',
#   'Prohibida - JEYSON x Jens LNG x El Tiex (Audio Oficial)',
#   239,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x Alexito FLPMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info@gmail.com',
#   'https://i.ytimg.com/vi/E7PjJTBuyL4/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gHCg2MA8=&rs=AOn4CLBGFlySRLd7xXjMwNK4OAUGlU3XXQ',
#   48542,
#   '2 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412512)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '47phcA27M14',
#   'Gángster De Boca - JEYSON x El Blopa (Video Oficial)',
#   201,
#   'Besito - Jeyson y El Zeta | Video Oficial#JEYSON #ELBLOPAPRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings...',
#   'https://i.ytimg.com/vi/47phcA27M14/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGF8gZShKMA8=&rs=AOn4CLB9Hy0rgM-xnEUbarlYNQ0pSx3_Dw',
#   158838,
#   '3 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412516)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '7ppDL_kEyQs',
#   'Besito - JEYSON x @ElZetaPty  (Video Oficial',
#   236,
#   'Besito - Jeyson y El Zeta | Video Oficial#JEYSON #ElZetaPRODUCCIÓN MUSICAL | KAKO PROD. x MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ Suscribete a @ElZetaPty GRM...',
#   'https://i.ytimg.com/vi/7ppDL_kEyQs/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBrBvT9GBg9mDbPYYtGaNdxUa623w',
#   153100,
#   '4 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412520)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '5vQ0aZHrS9M',
#   'Antrax 5.7 - JEYSON (Audio Oficial)',
#   195,
#   '#Antrax #5.7PRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info@gmail.com',
#   'https://i.ytimg.com/vi/5vQ0aZHrS9M/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGHIgTCgsMA8=&rs=AOn4CLBOK1ld9YvbKQ601a6-P2f4VY3PDA',
#   111165,
#   '4 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412524)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'fSQY4r9E5gY',
#   'Fake Friends - JEYSON x Choliare x Fugazis (Video Oficial)',
#   240,
#   'PROD. Muzikprado x JEREMIAH X JEAZY KAYVideo:Director-jeazy kayProductor-Ebenezer AudiovisualesPreductor ejecutivo-Beyond Music company & Alajuelita UndergroundFILM MAKER: CHK FILMS...',
#   'https://i.ytimg.com/vi/fSQY4r9E5gY/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGEggZShaMA8=&rs=AOn4CLA5_JiztpkbfGXIZrV15IkQ6RGlnQ',
#   277117,
#   '4 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412527)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '4M0nokGXOkA',
#   'PA Q GOCE - JEYSON x Mr Saik x Parrix (Hot Control Riddim) Visualizer',
#   237,
#   'Titulo: PA Q GOCE - Jeyson x mr saik x parrix (hot control riddim) visualizerPRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN...',
#   'https://i.ytimg.com/vi/4M0nokGXOkA/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gHSgtMA8=&rs=AOn4CLCbpsvnNo6z4758CcaKmDmFqPlitQ',
#   50392,
#   '6 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412531)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'CKL4bvD3MQo',
#   'Extasis - JEYSON (Audio Oficial)',
#   135,
#   '#Jeyson #ExtasisExtasis - JEYSON (Audio Oficial)PRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/CKL4bvD3MQo/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGBYgOyh_MA8=&rs=AOn4CLDlf4yNju-uLykIcR2LDPJbC2FI6A',
#   310722,
#   '6 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412534)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'venhYNraew0',
#   'Chernobyl - JEYSON (Audio Oficial)',
#   155,
#   '#Jeyson #MuzikPradoChernobyl - JEYSON (Audio Oficial)PRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507...',
#   'https://i.ytimg.com/vi/venhYNraew0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgWihRMA8=&rs=AOn4CLAVqVQVgBmnG2jZ6ySWn3gkriSp0Q',
#   530011,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412537)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'azgVOMGb8pU',
#   'Peligro De Extinción - JEYSON',
#   279,
#   '#RIP #Jeyson PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info@gm...',
#   'https://i.ytimg.com/vi/azgVOMGb8pU/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDVqrVSp0eON1xJT1NR3ljOkqSq7Q',
#   254039,
#   '8 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412540)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'y9VXrIGpS-0',
#   'Ghetto Party - JEYSON (Audio Oficial)',
#   152,
#   '#GhettoParty #Jeyson PRODUCCIÓN MUSICAL | MUZIK PRADO MANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info@gmail.com',
#   'https://i.ytimg.com/vi/y9VXrIGpS-0/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAJb82JTBfKqzaHeM3D6vRsoAWfcQ',
#   889066,
#   '9 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412543)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'udKlnjI_FKs',
#   'High Level - JEYSON ✘ SMILE BEATS',
#   158,
#   '#HighLevel #Jeyson #SmileBeatsPRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩...',
#   'https://i.ytimg.com/vi/udKlnjI_FKs/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCbvwv6iDnU-V2wk0vxpRV2DQ9oQw',
#   2182487,
#   '9 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412546)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'M7pqFJK25ZQ',
#   'Estigma (Suegra) -  JEYSON | Video Oficial',
#   211,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | THE MOBMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩...',
#   'https://i.ytimg.com/vi/M7pqFJK25ZQ/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBgM_5GL3fvfmcxchTcQu3iIN8Zlw',
#   674632,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412550)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '7cFk7aHrUuA',
#   'De 0 a 100 - JEYSON | Lyric Video',
#   142,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | BY DIEGO ARTMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/7cFk7aHrUuA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBR7vqiQsT3M_FbwZ7G5DhcXZeJFA',
#   259082,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412553)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '_4m9joNAMc0',
#   'Yo Te Llamo - JEYSON | Lyric Video',
#   154,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | BY DIEGO ARTMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/_4m9joNAMc0/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDDYxcZ3qsRyj7uBMc6ErCZIO0ZVw',
#   4508876,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412556)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '_oGI5r56sJQ',
#   'Exclusive - JEYSON | Lyric Video',
#   177,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | BY DIEGO ARTMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/_oGI5r56sJQ/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAYfIZih3rm0MH1qGXJNfzH4qrZnA',
#   2458405,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412558)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   '2Qx78-d3DZ4',
#   'Detalles - JEYSON | Lyric Video',
#   162,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | BY DIEGO ARTMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/2Qx78-d3DZ4/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBqEyCJZTJWqJL6O-a6NSX8ksHsQg',
#   233755,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412561)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'GBSyVfEIpKM',
#   'Expresiones - JEYSON ✘ @THEMOYS507 | Lyric Video',
#   160,
#   'PRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSPRODUCCION VISUAL | BY DIEGO ARTMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469...',
#   'https://i.ytimg.com/vi/GBSyVfEIpKM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB7O2g9EqVytkSpMvU8pKia1MTHJg',
#   1461711,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412564)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'Q1jgrrtpieQ',
#   'Secreto - JEYSON | Hottest Riddim',
#   147,
#   '#SECRETO #JEYSONPRODUCCIÓN MUSICAL | MUZIK PRADOMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️ Bookings +507 69277469📩 Email: jeyson.info@gmail.com',
#   'https://i.ytimg.com/vi/Q1jgrrtpieQ/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgSChGMA8=&rs=AOn4CLA0EHm1VpZXcd5slMmuU_F3bt9MeQ',
#   204145,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412567)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'UxL3mX1Tvgc',
#   'Mal Portada - JEYSON',
#   158,
#   'MAL PORTADA - JEYSON X SMILE BEATS X MUZIKPRADO#MalPortada #JEYSONPRODUCCIÓN MUSICAL | MUZIK PRADO x SMILE BEATSMANAGEMENT | @_smilebeats Suscribete a @JEYSON_ GRM Records And FLOW...',
#   'https://i.ytimg.com/vi/UxL3mX1Tvgc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBajVgLs2_vyBD2at0cgsI9pWagSA',
#   1128763,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412570)],
#  ['UCYt67-MBjYF5Y8RcEAjtq1g',
#   'h1ODta2-lvY',
#   'S.O.S - JEYSON ✘ MuzikPrado',
#   169,
#   'S.O.S - JEYSON X MUZIK PRADO#TuChacal #ValentinoGRM #JEYSON #SmileBeatsPRODUCCIÓN MUSICAL | MUZIK PRADOMANAGEMENT | @SmileBeatss Suscribete a @JEYSON_ GRM Records And FLOW AVN☎️...',
#   'https://i.ytimg.com/vi/h1ODta2-lvY/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCYBWcOHOfFn59H5nRjdN_-1vSziA',
#   98148,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 27, 412573)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'SRQx2dexb-0',
#   'একটু খানি দেখবো বলে // aktu khani dakbo bole // #song #tawsifmahbub #minar #keno',
#   342,
#   'একটু খানি দেখবো বলে / aktu khani dekbo bole #banglasong #tawsifmahbub #mehezabin #natoksong',
#   'https://i.ytimg.com/vi/SRQx2dexb-0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGEgYShhMA8=&rs=AOn4CLDoVRThfQNoPHz9q4_zQIj6zaI1lg',
#   21,
#   '8 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484085)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   '4tAeP7mDpPc',
#   'cholo Bangladesh// চলো বাংলাদেশ #grameenphone',
#   161,
#   'cholo Bangladesh#bangla_song #cholo_bangladesi#bangladesh #gp #best_song #top #tending#grameenphone',
#   'https://i.ytimg.com/vi/4tAeP7mDpPc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHUBoAC4AOKAgwIABABGBwgZShBMA8=&rs=AOn4CLCx110HvQUpjkEvBQjE1SFkgwNmiQ',
#   22,
#   '11 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484121)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'zbAgMKLlEXg',
#   'তোমার রিদয় মাঝে রাখবো ছেড়ে যাবোনা  // tomr ridoy maje rakbo sera jabo na #arfan_nisho #mehejabin',
#   194,
#   'তোমার রিদয় মাঝে রাখবো ছেড়ে যাবোনা tomr ridoy maje rakbo sera jabo na #bangla_song #viral #whatsapp_status #tending',
#   'https://i.ytimg.com/vi/zbAgMKLlEXg/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-BIAC4AKKAgwIABABGGUgVihQMA8=&rs=AOn4CLAgw2tvpF_qC7tK_m8bQDClNw4aRQ',
#   33,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484130)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'C_Un--PncMo',
#   'bol tui amar sera kothai jabi // বল তুই আমার ছেড়ে কোথায় যাবি #bangla_song',
#   315,
#   'bol tui amar sera kothai jabi #bangla_song #lovesong #viral',
#   'https://i.ytimg.com/vi/C_Un--PncMo/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGHIgXig3MA8=&rs=AOn4CLCnVIL8LZhVHSpbrxi_5a8dtDo5FA',
#   7039,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484138)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'GIn1VgA4RVk',
#   'তোর মন খারাপের দেশে // mon khrap  #arfan_nisho #bangla_song #nadiya',
#   319,
#   'তোর মন খারাপের দেশে #arfan_nisho #banglasong  #monkharap #nadia #natoksong #viral',
#   'https://i.ytimg.com/vi/GIn1VgA4RVk/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-BIAC6AKKAgwIABABGE4gZShgMA8=&rs=AOn4CLCba7Ll7vuSLWRnNBFI5ujIQ3t4fA',
#   22072,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484144)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'j2y1FiTK6Lo',
#   'ভালোবেসে হাতটি ধরো #imrankhan',
#   322,
#   'ভালোবাসি কেনো বুঝনা #emraan #imran',
#   'https://i.ytimg.com/vi/j2y1FiTK6Lo/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGD4gWChlMA8=&rs=AOn4CLCzdJaQ-03Y1FeFyjkSAklRjoNWmg',
#   385,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484181)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   '5L9wYKT-JBE',
#   'পরের যায়গা পরের গাড়ী  copyright ©️',
#   328,
#   'song copyright ©️',
#   'https://i.ytimg.com/vi/5L9wYKT-JBE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AGOA4AC4AGKAgwIABABGGUgVihJMA8=&rs=AOn4CLDiHwias_-voR0aqVmlYgM5OrIPhw',
#   44,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484187)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'V-apmUx5ChA',
#   'রাতের পাদ্মা সেতু ভ্রমন',
#   136,
#   'রাতের পাদ্মা সেতু ভ্রমন #padmabridge #jonny #night #padma #padma_bridge_live #padma_satu #dhaka #khulna #babubazar#shorts #viral #india #bangladesh #best...',
#   'https://i.ytimg.com/vi/V-apmUx5ChA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBCiQIc4UUADl2hK5ZytgkE8Eoq3g',
#   60,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484192)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'GH5iGEiPNxI',
#   'bus gaming mobile #busgames',
#   70,
#   '@bdbusloverml thanks ato sundor obb jonno #viral #best #busgames #bd #buslover #bangladesh #india #usa #saudiarabia #dubai #love #shorts ##bussimulatorindonesia #indian #bd #mood #moodstatus',
#   'https://i.ytimg.com/vi/GH5iGEiPNxI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDlpsKgbb7h5onV_LHf-optq0AxtQ',
#   40,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484198)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'MjpR0uHjnaw',
#   'Bus gaming mobile',
#   207,
#   '#bussimulatorindonesia #shorts',
#   'https://i.ytimg.com/vi/MjpR0uHjnaw/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB5kotY3aPFsZk7gzu3ygD6rYXNiQ',
#   15,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484203)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'Ia2KjQrTAZk',
#   'Bangladesh railway station chuadanga #bdrailway',
#   63,
#   '#chuadanga #viral #traintravel',
#   'https://i.ytimg.com/vi/Ia2KjQrTAZk/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AGUA4AC0AWKAgwIABABGGUgXChZMA8=&rs=AOn4CLAp0vI5WEemt1izvV7bNowG4WAZvA',
#   21,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484208)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'iPpG6loTs1g',
#   'bus simulator Indonesia',
#   20,
#   'bus simulator Indonesia.. play mobile moods',
#   'https://i.ytimg.com/vi/iPpG6loTs1g/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDQ4hBl_yNCLRtWdltEAArVHJD5FA',
#   10,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484213)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'vL7jdBr6PV4',
#   'চুয়াডাঙ্গা রেলওয়ে স্টেশনে যখন মালবাহি ট্রেন প্রবেশ করে',
#   63,
#   'মালবাহী ট্রেন চুয়াডাঙ্গা স্টেশন ।। ট্রেন এর সাউন্ড ফিল করুন',
#   'https://i.ytimg.com/vi/vL7jdBr6PV4/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AGUA4AC0AWKAgwIABABGHIgWCgyMA8=&rs=AOn4CLA7sCZM3jWPY5KdVL7jL3KNhMczBQ',
#   21,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484218)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'iIJOVXuWnPo',
#   'ওভার টেক করতে গিয়ে যখন মাঠের ভিতর চলে যায়,',
#   18,
#   'bus, simulator Indonesia bslb, with royal express',
#   'https://i.ytimg.com/vi/iIJOVXuWnPo/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLA4PUTeXFvAK_0uoKSEdawWoN4u5A',
#   28,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484223)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'hJHV3GGvz3k',
#   'bus simulator Indonesia.. official trip.. Bangladesh map .. royal express',
#   92,
#   '',
#   'https://i.ytimg.com/vi/hJHV3GGvz3k/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLABm3JNknE1Q4jDKD2UWNMDAptImw',
#   56,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484228)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'V22GteHS0pg',
#   'কাল বৈশাখীর দমকা হাওয়া',
#   34,
#   'শুক্রবার বিকাল ৪ টা থেকে শুরু হয়',
#   'https://i.ytimg.com/vi/V22GteHS0pg/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLDuL0nOPCeSXK9oGOwuyBoHfIb-HQ',
#   6,
#   '2 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484233)],
#  ['UCYig0vJRD03a6lkqWrbP8xg',
#   'V2vmRUVvzMY',
#   'Ami valo nai tumi sara....',
#   120,
#   'Saeid #viral #funny #status #story #statusvideo',
#   'https://i.ytimg.com/vi/V2vmRUVvzMY/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC4MGIVP42M7F4hRvf6drN9CLFVow',
#   321,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 30, 484238)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '_amXH_bMhwU',
#   'DESPACITO - Luis Fonsi ft Daddy Yankee - 🔴 INSCREVA-SE @ninamaya',
#   230,
#   'http://instagram.com/ninnamaya  Instagram @ninnamayaSE INSCREVAM NO CANAL e Confira a coreografia Passo a passo https://youtu.be/N5LQmAet0hA fiquem ligados nos nossos próximos vídeos 😘💕...',
#   'https://i.ytimg.com/vi/_amXH_bMhwU/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGEgYShhMA8=&rs=AOn4CLALDKt7yJT1-E8F9s1YBtVuG8WM-w',
#   56170845,
#   '7 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29893)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'UUB_45b2IuI',
#   'NÃO SE APAIXONA - Jerry Smith e MC Loma e As Gêmeas Lacração by Cia Nina Maya',
#   229,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com http://instagram.com/ninnamaya http://instagram.com/kelly.brag...',
#   'https://i.ytimg.com/vi/UUB_45b2IuI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBgO527YFzn0Xjfz-DSM6k9G2xxGg',
#   5349185,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29930)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '5KzAJVrrir4',
#   'OPA OPA - MC WM e Jerry Smith feat. DJ Pernambuco - Cia NinaMaya',
#   215,
#   'Nosso insta http://instagram.com/canalninamayahttp://instagram.com/ninnamaya http://instagram.com/giulianacavalierihttp://instagram.com/MaycadelduqueApoio Musitec, Academia Six wellness...',
#   'https://i.ytimg.com/vi/5KzAJVrrir4/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBKff4MjoOG_ALTIiQQdRRiizmL8Q',
#   4579609,
#   '7 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29943)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'ohWwB_ZYVh0',
#   'GUERRA DE BUNDA - Dennis feat. MC Jefinho e MC Maromba by Cia Nina Maya (Coreografia)',
#   207,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Participação : http://instagram.com/adhara_schluckebier...',
#   'https://i.ytimg.com/vi/ohWwB_ZYVh0/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBYLcdjW7j0yjdUiz2GFolIOD7eVQ',
#   3704233,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29952)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'FlcYOLMdwmY',
#   'PAMPUDA - MC WM, MC Leléto, Os Cretinos e DJ Gege by Nina Maya',
#   194,
#   '@ninnamaya Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com  Nina Maya: @ninnamaya https://instagram.com/ninnamaya...',
#   'https://i.ytimg.com/vi/FlcYOLMdwmY/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDhzEQlx7rkVKW6UGgJDClSVhalEg',
#   2881631,
#   '5 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29961)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'oYVeU3Zx5_o',
#   'VAI MALANDRA - Anitta, Mc Zaac, Maejor ft. Tropkillaz & DJ Yuri Martins by Cia Nina Maya',
#   231,
#   'Shopping Boulevard Rio Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com http://instagram.com/ninnamaya ...',
#   'https://i.ytimg.com/vi/oYVeU3Zx5_o/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCfksAAoputvU6FV7vlSZgpNR6YIg',
#   2188398,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29970)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '-CD3tQlXg0s',
#   'RABETÃO - Mc Lan - 🔴 INSCREVA-SE Cia NinaMaya',
#   244,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamayahttp://instagram.com/ninnamaya http://instagram.com/giulianacavalierihttp://instagram.com/willia...',
#   'https://i.ytimg.com/vi/-CD3tQlXg0s/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB7XjVVPqyMC1hjzS0zrWe8rShRkg',
#   2079944,
#   '7 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29977)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'Rh1G2IQNvGM',
#   'SAPEQUINHA - Lexa e Mc Lan By Nina Maya',
#   154,
#   'Contato para Shows, parceria e eventos Direct no insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia Originalhttp://instagram.com/ninnamaya Apoio Musitec,...',
#   'https://i.ytimg.com/vi/Rh1G2IQNvGM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAsQImbXeZYkHiDC1Z-LOsaHyGEFA',
#   1190145,
#   '5 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29985)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'nfCWpiWuLrI',
#   'VAMOS PRA GAIOLA - Kevin o Chris Feat. FP do Trem Bala by Nina Maya',
#   158,
#   '@ninnamaya parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com  Nina Maya: @ninnamaya https://instagram.com/ninnamayaCanal da Aline:...',
#   'https://i.ytimg.com/vi/nfCWpiWuLrI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLANTlx__-dFv7p_hfCsBMdOUJh-ZA',
#   1113624,
#   '5 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29992)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'KS-ZQ-VAGqc',
#   'ABUSADAMENTE - MC Gustta e MC DG ♦️INSCREVA-SE - Cia NinaMaya',
#   229,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia Nina Mayahttp://instagram.com/ninnamayaLook...',
#   'https://i.ytimg.com/vi/KS-ZQ-VAGqc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBOENLZuWktxiCUwI4mNBiuvXF77g',
#   1089134,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 29999)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'CJLhAF8EKNM',
#   'NOSSA QUE ABSURDO - Jerry Smith & MC Nando DK by Cia NinaMaya',
#   174,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia Nina Mayahttp://instagram.com/ninnamayaApoio...',
#   'https://i.ytimg.com/vi/CJLhAF8EKNM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAHK40zCdP2tuAruz3z6kzBxQh6_g',
#   1055373,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 30011)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'n8u_zS5Ff7w',
#   'NÃO SE APAIXONA - hoje é dia de TBT by NinaMaya',
#   221,
#   '@ninnamaya parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com  Nina Maya: @ninnamaya https://instagram.com/ninnamaya  academia:...',
#   'https://i.ytimg.com/vi/n8u_zS5Ff7w/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBwYiD0JYyYjSCpWH8xIKhjo6ppJg',
#   999448,
#   '4 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 30018)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'Y7Dw2dDQk8U',
#   'Automaticamente - MC Leléto e MC Maromba - by Cia NinaMaya',
#   243,
#   'http://instagram.com/ninnamayaParticipação especial @camilarossadoCanal Pira não: https://www.youtube.com/channel/UCRY5Ex9MEDYHuZPZcYjmb7w http://instagram.com/giulianacavalieri...',
#   'https://i.ytimg.com/vi/Y7Dw2dDQk8U/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDlwwrR5UKwfM-GFwX0ykEIjp6n3A',
#   882569,
#   '7 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 30026)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'aSGYV6dQS2c',
#   'KIKADINHA - Jerry Smith - NinaMaya',
#   177,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia Original/ adap Cia Daniel Saboya http://instagram.co...',
#   'https://i.ytimg.com/vi/aSGYV6dQS2c/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDcCFMX6H5DqZ8fPh1ESZndnb_VGA',
#   790763,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 36, 30034)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   
],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'A3sMdhkuGDM',
#   'Entrevista Cia Daniel Saboya by NinaMaya Up',
#   608,
#   'Contato  📩 ninamaya.nm@gmail.com.     http://instagram.com/ninnamaya       Programa de variedades apresentado por Nina Mayahttp://instagram.com/ninnamayahttp://instagram.com/danielsaboya...',
#   'https://i.ytimg.com/vi/A3sMdhkuGDM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGFUgXChlMA8=&rs=AOn4CLC4aDdAJ0aSFdpKmAd8kckxWYUSCg',
#   190092,
#   '10 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208544)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'YAm80wmP3Mk',
#   'COMBATCHY - Anitta, Lexa  Luísa Sonza Feat. MC Rebecca by Nina Maya',
#   180,
#   '',
#   'https://i.ytimg.com/vi/YAm80wmP3Mk/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDksLFh2nXKwSYl--xTYsWa4Yat6Q',
#   166100,
#   '4 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208559)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'PqTKW999kZM',
#   'FULERAGEM - MC WM By Cia Nina Maya',
#   172,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia Original com adaptações http://instagram.com/ninna...',
#   'https://i.ytimg.com/vi/PqTKW999kZM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB4-optK_vGnEgztfyEc--TjERmIg',
#   158422,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208566)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'nKEDWP6GqKg',
#   'ENVOLVIMENTO - MC Loma by Cia Nina Maya (CARNAVAL)',
#   179,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com http://instagram.com/ninnamaya http://instagram.com/Adrianooliv...',
#   'https://i.ytimg.com/vi/nKEDWP6GqKg/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC39OmLWoWMAuhQDlUn7GRjUr8pjw',
#   149316,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208576)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '4fTRp6c8iVU',
#   'ROMANCE COM SAFADEZA - Wesley Safadão e Anitta by Cia Nina Maya',
#   203,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia @kelly.braggiohttp://instagram.com/ninnamaya...',
#   'https://i.ytimg.com/vi/4fTRp6c8iVU/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLA56WZA9WCjvJSK4O9Vu7OXeT8WmQ',
#   144839,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208585)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'PeadaxkNJek',
#   'TUDO OK - Thiaguinho Mt Feat. Mila by Nina Maya',
#   202,
#   '@ninnamaya@sixathleticclub@dansa.oficial',
#   'https://i.ytimg.com/vi/PeadaxkNJek/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAoKdBpggqH40O4o8S6_XtTzjUN7g',
#   140334,
#   '4 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208593)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'sjpwEWTIpsQ',
#   'AMOR DE VERDADE - MC Kekel e MC Rita by Cia Nina Maya',
#   218,
#   'Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com Coreografia: Paula Amoedohttp://instagram.com/ninnamaya...',
#   'https://i.ytimg.com/vi/sjpwEWTIpsQ/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDxVPhFFmCcKzdk7JF8QrESiuVFxg',
#   139398,
#   '6 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208601)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '2CTfIY9CWZ0',
#   'Mc Tarapi&Neblina- Quando o Dj Mandar - Cia NinaMaya',
#   226,
#   'Ediação e captação @ninaphotostudioemail p contato ninamaya.nm@gmail.comInstagran: http://Instagram.com/ninnamaya',
#   'https://i.ytimg.com/vi/2CTfIY9CWZ0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgUChPMA8=&rs=AOn4CLDl3ZR5CXPjG6yG5jIwigrwj71Z8Q',
#   130914,
#   '10 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208610)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '25yELhQAYfU',
#   'REBOLARIZANDO - Jojo Moronttinni feat. MC Pocahontas by Nina Maya',
#   189,
#   '@ninnamaya Contato para Shows, parceria e eventos Direct no Nosso insta http://instagram.com/canalninamaya ou e-mail: ninamaya.nm@gmail.com  Nina Maya: @ninnamaya https://instagram.com/ninnamaya?...',
#   'https://i.ytimg.com/vi/25yELhQAYfU/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAUuWmXVub9P1EuKdttyiPebSU-Dw',
#   128787,
#   '5 years ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 208618)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'l5fTHOD7Ouw',
#   'PIPOCO - Vídeo Aula by Nina Maya',
#   359,
#   'Aula para Iniciante com a Prof. Nina Maya',
#   'https://i.ytimg.com/vi/l5fTHOD7Ouw/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDVkFsHmrLVlsJr7rzk4tskHy4bkQ',
#   461,
#   '3 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492871)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'q_cFzLk-118',
#   'AULA PARA INICIANTES By Nina Maya',
#   579,
#   '',
#   'https://i.ytimg.com/vi/q_cFzLk-118/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDd9ZuZDs55UTQpS_H1v9H2SwA34A',
#   213,
#   '4 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492916)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '1WWGlpAGjvA',
#   'POC POC - PEDRO SAMPAIO by NINA MAYA',
#   308,
#   'Me sigam no Instagram @ninamaya',
#   'https://i.ytimg.com/vi/1WWGlpAGjvA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCJAUOB0jtxW4pcqIFENbR9tDMlyA',
#   428,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492928)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'MZbesesusoM',
#   'ENTÃO VAI - ZÉ FELIPE by NINA MAYA',
#   593,
#   'Me sigam no Instagram @ninamaya',
#   'https://i.ytimg.com/vi/MZbesesusoM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC9mj35QoIgzxkK4dq_HyM8jheM0g',
#   327,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492939)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'ahvHgerLqrw',
#   'Corte NinaCast - YCD - Fly Vagner',
#   60,
#   'Corte do NinaCast com Fly VagnerEdição do Corte: Fly VagnerGravado na Znit Produtora #podcast #DaddyKall#FlyVagner#Znit#NinaMaya#bmb #BrassilMelodyBand',
#   'https://i.ytimg.com/vi/ahvHgerLqrw/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAcSqtQZEJZCwbeFEkNiofbu4SDDw',
#   131,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492949)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '75lfE4nzs90',
#   'Corte NinaCast - YCD - Daddy Kall',
#   192,
#   'Corte do NinaCast com Daddy Kall Edição do Corte: Fly VagnerGravado na Znit Produtora #podcast #Daddy Kall#Fly Vagner#Znit#Nina Maya#bmb #Brassil Melody Band',
#   'https://i.ytimg.com/vi/75lfE4nzs90/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDDOglnxq76q2VQishflZbd2fsA9A',
#   84,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492963)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'uNiHYztKZec',
#   'NinaCast -  Fly Vagner e Daddy Kall - YouCanDance',
#   10192,
#   'Um bate-papo pra lá de descontraído com os amigos integrantes do You Can Dance, Fly Vagner e Daddy Kall, falando sobre dança, TV, vida pessoal e muito mais.#podcast #ycd #flyvagner#daddykal...',
#   'https://i.ytimg.com/vi/uNiHYztKZec/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAXYGq8mLMIF1wrff_WIEZb98S_KA',
#   454,
#   '7 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492975)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'MpAvmAc_7Tc',
#   'NinaCast  Convida - Gisa Garcia, Mauro Garcia e Lidiane Sôuza',
#   9832,
#   'NinaCast  Convida - Gisa GarciaAmigos e familiares contam sobre a vida e a obra de MC Marcinho o Príncipe do Funk00:00 Abertura00:30 Introdução04:00 O Começo05:30 Pra Começar...',
#   'https://i.ytimg.com/vi/MpAvmAc_7Tc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBNAeuuPXhFZIZw0GplW0k-ut5aKA',
#   5922,
#   '8 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492983)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'oYmU5Xy6Q7Q',
#   'NinaCast Convida Nunes, "O Artilheiro Das Grandes Decisões"',
#   4250,
#   'NUNES, "O ARTILHEIRO DAS GRANDES DECISÕES"00:00 - ABERTURA00:30 - APRESENTAÇÃO01:26 - ARTILHEIRO DAS GRANDES DECISÕES02:26 - O INÍCIO08:00 - A PRIMEIRA VEZ11:40 - A CIGANA ...',
#   'https://i.ytimg.com/vi/oYmU5Xy6Q7Q/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLD5HPL48f6rTfgcJWWp19exddIb3A',
#   247,
#   '8 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 492992)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'UFXTppY_tQ8',
#   'NinaCast Convida Mauricio Manfrini',
#   9889,
#   'Nina Maya tem um papo descontraído com Mauricio Pereira Ribeiro.  Ator, humorista, locutor, dublador, cantor, músico e compositor. Conhecido pelo nome artístico “Maurício Manfrini”...',
#   'https://i.ytimg.com/vi/UFXTppY_tQ8/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBwRA7ZTFh8Z-dBup56S6IC4ATa1Q',
#   3456,
#   '9 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493006)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '_iw5KXD1BFQ',
#   'NinaCast - Mica Condé',
#   3472,
#   '',
#   'https://i.ytimg.com/vi/_iw5KXD1BFQ/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC01SXUGghTHeBsEndnMoPiCtLsdA',
#   314,
#   '9 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493015)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'IaP4fGQuSsk',
#   'O dia que dancei com David Brasil a Trend Papagaio falante 🦜',
#   171,
#   '',
#   'https://i.ytimg.com/vi/IaP4fGQuSsk/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAe4c6xyt9udSShtAdZNcPYk9wbkQ',
#   207,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493022)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'mmXXqDoPSME',
#   'Barbie girl - NinaMaya',
#   139,
#   '',
#   'https://i.ytimg.com/vi/mmXXqDoPSME/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgSShFMA8=&rs=AOn4CLD5PsNNKU_ftPvVNLMi-UGSjV-gpg',
#   611,
#   '10 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493029)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'BX6FB1irhhk',
#   'Fanáticos Pelo Vinho',
#   322,
#   '',
#   'https://i.ytimg.com/vi/BX6FB1irhhk/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCLHfv7vkjZm_gFTnx14PUACUlpNw',
#   314,
#   '11 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493035)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'EHAomtVIVyo',
#   'Boot Lovers - Kelly Braggio',
#   615,
#   '',
#   'https://i.ytimg.com/vi/EHAomtVIVyo/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAUv8u80i7q1tmmumvhuEVSSBR-mQ',
#   201,
#   '11 months ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493042)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'B0-hsNxlgys',
#   'Aulão de Dança - Priscila Fimo',
#   1508,
#   '',
#   'https://i.ytimg.com/vi/B0-hsNxlgys/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLD_3Msm_E0fEpLSzKAytU7FDed1ig',
#   306,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493049)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'VNAkr8tKzoI',
#   'APETITOSA - ROGERINHO  / Nina Maya (Coreografia Dan-Sa)',
#   137,
#   '',
#   'https://i.ytimg.com/vi/VNAkr8tKzoI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAraD9X2gb24ORaGZ_AUEJKFdVTzQ',
#   1193,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493055)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'L26No19gXcg',
#   'VUK VUK - VIDEO AULA - convidada - GIULIANA CAVALIERI',
#   553,
#   '',
#   'https://i.ytimg.com/vi/L26No19gXcg/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDgzSIw_s-5eKB6tMcbwEZDsbHVSQ',
#   283,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493061)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '2buihQXYdzI',
#   'APETITOSA - VIDEO AULA - Convidada: GIULIANA CAVALIERI',
#   763,
#   'https://youtu.be/2buihQXYdzI ao vivoSeja um instrutor DANSA https://www.dansa.com.br/cursodansaCUPOM DE DESCONTO NINA50',
#   'https://i.ytimg.com/vi/2buihQXYdzI/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCkl9g6D0CAiDWyRkcE0fhn_GTewg',
#   640,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493067)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   'Zc0egfBS38Q',
#   'NinaCast convida DJ Marlboro',
#   6476,
#   'Canal do DJ Marlboro https://youtu.be/1FZ4fQkW2wI',
#   'https://i.ytimg.com/vi/Zc0egfBS38Q/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAjnFW3neMrU53uuSgAeEumUI9gGg',
#   330,
#   '1 year ago',
#   datetime.datetime(2024, 8, 23, 13, 46, 37, 493075)],
#  ['UCOTXKyzvDOqDGDKhuScHOag',
#   '1E8e-TwIT8A',
#   'BANDA BMB - (BRASSIL MELODY BAND) - MEDLEY BAILE FUNK',
#   547,
#   'Banda BMB: Uma fusão única de Funk, Black Music, Hip Hop e Pop.  A banda carioca BMB está pronta para conquistar o cenário musical com seu estilo inovador. Com referências que vão desde...',
#   'https://i.ytimg.com/vi/1E8e-TwIT8A/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDHeU2ov-WS3BiHicQsnKV1ETq_lQ',
#   221,
#   '1 year ago',
# ...
#   12,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313232)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '-madkYag4yM',
#   'ハノン\u3000HANON_01_T240',
#   32,
#   '独学PIANO練習HANON_012オクターブTempo＝240独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-1.html',
#   'https://i.ytimg.com/vi/-madkYag4yM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQigfMA8=&rs=AOn4CLAYlHqvOC6RbQg3ITI4MGaXJhwokg',
#   28,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313235)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'ss9byICLEl8',
#   'ハノン\u3000HANON_01_T140',
#   54,
#   '独学PIANO練習HANON_012オクターブTempo＝140独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-1.html',
#   'https://i.ytimg.com/vi/ss9byICLEl8/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGHIgRig6MA8=&rs=AOn4CLDgx7A9CL6K6F5tXVQPgV4IloxgpQ',
#   30,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313239)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '2ujumbad4k4',
#   'ハノン\u3000HANON_01_T160',
#   47,
#   '独学PIANO練習HANON_012オクターブTempo＝160独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-1.html',
#   'https://i.ytimg.com/vi/2ujumbad4k4/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQigdMA8=&rs=AOn4CLCDtTPJudCC0nEDijzcGO39gBi4nQ',
#   31,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313242)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'jsoDKcS27AY',
#   'Bach_BWV_846_01 平均律クラヴィーア曲集 第1巻 第1番',
#   183,
#   'Bach平均律クラヴィーア曲集 第1巻 第1番第１曲プレリュード BWV 846独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-2.html',
#   'https://i.ytimg.com/vi/jsoDKcS27AY/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQCgbMA8=&rs=AOn4CLD2ImPTd-1wU4QyBX3qqmG5kwMusA',
#   42,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313245)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'qyPtlQSub_A',
#   'Bach_BWV_846_02 平均律クラヴィーア曲集 第1巻 第1番',
#   152,
#   'Bach平均律クラヴィーア曲集 第1巻 第1番第１曲プレリュード BWV 846独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-2.html',
#   'https://i.ytimg.com/vi/qyPtlQSub_A/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGDIgRCh_MA8=&rs=AOn4CLBoJyszW_0hvoLHsZxnNsj9_1njJg',
#   20,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313248)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'oLILwEOo2rw',
#   'Bach_BWV_846_03 平均律クラヴィーア曲集 第1巻 第1番',
#   138,
#   'Bach平均律クラヴィーア曲集 第1巻 第1番第１曲プレリュード BWV 846独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-2.html',
#   'https://i.ytimg.com/vi/oLILwEOo2rw/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gPygZMA8=&rs=AOn4CLBIsTk2v6qOgV9wDMxq5tOOXTA33A',
#   15,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313251)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'NW0aTfxVRLI',
#   'Bach_BWV_846_04 平均律クラヴィーア曲集 第1巻 第1番',
#   126,
#   'Bach平均律クラヴィーア曲集 第1巻 第1番第１曲プレリュード BWV 846独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-2.html',
#   'https://i.ytimg.com/vi/NW0aTfxVRLI/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gSCgwMA8=&rs=AOn4CLDw06kfbKC7nFtbnir6cJAIdAVqWA',
#   34,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313254)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'SvaXwyoO2ME',
#   'Bach_BWV_846_05 平均律クラヴィーア曲集 第1巻 第1番',
#   114,
#   'Bach平均律クラヴィーア曲集 第1巻 第1番第１曲プレリュード BWV 846独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-2.html',
#   'https://i.ytimg.com/vi/SvaXwyoO2ME/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQCgeMA8=&rs=AOn4CLAuGntI9-rmVr7-Bjw2Tf9G4e7DOQ',
#   36,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313257)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'jwbUfFxeyrE',
#   'Beethoven_Bagatelle_No.25_in_A minor_01  エリーゼのために  ベートーヴェン',
#   525,
#   'エリーゼのために  ベートーヴェンFür EliseBeethoven独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-4.html',
#   'https://i.ytimg.com/vi/jwbUfFxeyrE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLCCdZ8QnX4tJgoClDEZZkwVoIPAEA',
#   39,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313260)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '6MC5FH_F7ow',
#   'Beethoven_Bagatelle_No.25_in_A minor_02  エリーゼのために  ベートーヴェン',
#   297,
#   'エリーゼのために  ベートーヴェンFür EliseBeethoven独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-4.html',
#   'https://i.ytimg.com/vi/6MC5FH_F7ow/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gHCgYMA8=&rs=AOn4CLAArsHVq51lIexdjATOOASQBDUbKQ',
#   23,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313263)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'lKFKy2q6asM',
#   'Beethoven_Bagatelle_No.25_in_A minor_03  エリーゼのために  ベートーヴェン',
#   253,
#   'エリーゼのために  ベートーヴェンFür EliseBeethoven独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-4.html',
#   'https://i.ytimg.com/vi/lKFKy2q6asM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gRSglMA8=&rs=AOn4CLAYlT-t3Tzim7uaIBaWrjbcYwKIRA',
#   13,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313266)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'Lz5z-yEpbV4',
#   'Beethoven_Bagatelle_No.25_in_A minor_04  エリーゼのために  ベートーヴェン',
#   205,
#   'エリーゼのために  ベートーヴェンFür EliseBeethoven独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-4.html',
#   'https://i.ytimg.com/vi/Lz5z-yEpbV4/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGEsgTyhlMA8=&rs=AOn4CLA8hcn2WGvpylqV1jm_jn7f1vUh1A',
#   9,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313269)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'kkfzwDeC77k',
#   'Beethoven_Bagatelle_No.25_in_A minor_05  エリーゼのために  ベートーヴェン',
#   128,
#   'エリーゼのために  ベートーヴェンFür EliseBeethoven独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-4.html',
#   'https://i.ytimg.com/vi/kkfzwDeC77k/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGHIgQyg4MA8=&rs=AOn4CLDQa3Ph-79_I9v4v4pvm3y_PoO-FQ',
#   16,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313272)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'bZ6PZghlvVs',
#   'Chopin_Prelude_Op28_No4_03 ショパン : 24のプレリュード（前奏曲集） Op.28   4番',
#   121,
#   'ショパン : 24のプレリュード（前奏曲集） Op.28   4番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-30.html',
#   'https://i.ytimg.com/vi/bZ6PZghlvVs/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBfBqoLZRnonfEMWJ_ukviJrWgUGA',
#   12,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313275)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '2j9qy6aeaHA',
#   'Chopin_Prelude_Op28_No4_02 ショパン : 24のプレリュード（前奏曲集） Op.28   4番',
#   146,
#   'ショパン :24のプレリュード（前奏曲集） Op.28   4番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-30.html',
#   'https://i.ytimg.com/vi/2j9qy6aeaHA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCAGG6EBI10YiU02FOPB4VJs5alsA',
#   4,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313278)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'ywzuXA-A69I',
#   'Chopin_Prelude_Op28_No4_01 ショパン : 24のプレリュード（前奏曲集） Op.28   4番',
#   194,
#   'ショパン :24のプレリュード（前奏曲集） Op.28   4番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-30.html',
#   'https://i.ytimg.com/vi/ywzuXA-A69I/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCSr-etkj7gwz00INNxcplKUlNFEQ',
#   17,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313281)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '5Plrsdrc2-0',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T120',
#   61,
#   'HANON_022オクターブTempo＝120独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/5Plrsdrc2-0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGBsgNih_MA8=&rs=AOn4CLCrEzPksEUcwMm8-PPXGd7Ko7KxcQ',
#   19,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313283)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'l3pL78PRqxM',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T140',
#   52,
#   'HANON_022オクターブTempo＝140独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/l3pL78PRqxM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGHIgPyg_MA8=&rs=AOn4CLCNZmISU-WvXS89iYqdPWh4IGazFA',
#   14,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313286)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'eAXr8n0yfC8',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T160',
#   45,
#   'HANON_022オクターブTempo＝160独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/eAXr8n0yfC8/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGB0gNih_MA8=&rs=AOn4CLDwoqM1ZLK-t021Tmm-5uoJz4pk9A',
#   11,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313290)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '8pXB-cO49Dw',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T180',
#   41,
#   'HANON_022オクターブTempo＝180独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/8pXB-cO49Dw/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQCgbMA8=&rs=AOn4CLBUE2pQv3-VNyFKHW2vRS1yRDoEEg',
#   4,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313293)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '6q-VVhDMUNc',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_02_T200',
#   37,
#   'HANON_022オクターブTempo＝200独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/6q-VVhDMUNc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGBsgNSh_MA8=&rs=AOn4CLBa5naAuEL5o2EmEYB9peSoiiUR9A',
#   5,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313297)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'pPWi46Z_ZoE',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T220',
#   34,
#   'HANON_022オクターブTempo＝220独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/pPWi46Z_ZoE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGHIgTyhCMA8=&rs=AOn4CLCs-1wbI2LrV2ZaJBRW2LqwCXFVaw',
#   6,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313299)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'gQXLZFgkz7Q',
#   '全調（黒鍵）ハノン\u3000第2番\u3000ALL Keys HANON_02_T240',
#   32,
#   'HANON_022オクターブTempo＝240独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-9.html',
#   'https://i.ytimg.com/vi/gQXLZFgkz7Q/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGCAgOCh_MA8=&rs=AOn4CLCcGpb0obJifak6rc7t1NXwAhQtoA',
#   10,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313302)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'kln5QEgXta4',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T120',
#   37,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/kln5QEgXta4/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gRCgiMA8=&rs=AOn4CLAzFeBslCqHIGFYK0USPIGBtZYotw',
#   52,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313305)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'vuCNYKSTnHw',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T140',
#   31,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/vuCNYKSTnHw/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gRSgmMA8=&rs=AOn4CLAuvjaZt6nbLuyPDFj-_a1pGUJN6w',
#   41,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313308)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'tLs0n-6FPJE',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T160',
#   28,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/tLs0n-6FPJE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGC4gQih_MA8=&rs=AOn4CLBBEe5ZFyyrh4Jy8IWUlzHiBGbaDA',
#   29,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 35, 313311)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'SAqKUv3lt1E',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T180',
#   26,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/SAqKUv3lt1E/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gRygwMA8=&rs=AOn4CLAr53djN1souB2kW_3vgACq82OdpA',
#   26,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485073)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'T1my-YbMcpE',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T200',
#   23,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/T1my-YbMcpE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGB8gNyh_MA8=&rs=AOn4CLAJaimmUJdO4p5G_S38iQsInURCkg',
#   28,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485109)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   '7P3jFwNQVoY',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T220',
#   22,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/7P3jFwNQVoY/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gJygUMA8=&rs=AOn4CLBBxjNTJ2zlv6c0Qx_gk33R1_xQTw',
#   18,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485118)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'URC-Teze17M',
#   '全調（黒鍵）ハノン\u3000第39番\u3000ALL Keys HANON_39_C_Major_T240',
#   20,
#   '独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-10.html',
#   'https://i.ytimg.com/vi/URC-Teze17M/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGGUgXShNMA8=&rs=AOn4CLCEKw-1rGy5OCNcbI20jhQ63QynKA',
#   24,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485126)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'GQqHxIKNc60',
#   'czerny_30_01_01 ツェルニー30番練習曲 １番',
#   130,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/GQqHxIKNc60/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGEkgSyhlMA8=&rs=AOn4CLA0tmsYlLkTh56Zb1BboJUVQfMlhQ',
#   27,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485133)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'gbUGdRNmL_Y',
#   'Czerny_30_01_02 ツェルニー30番練習曲 １番',
#   109,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/gbUGdRNmL_Y/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gLygXMA8=&rs=AOn4CLBeCzrAyfMZ6AX4bclVPYD30QTIRA',
#   20,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485141)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'Y3ZA1-X-c6M',
#   'Czerny_30_01_03 ツェルニー30番練習曲 １番',
#   90,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/Y3ZA1-X-c6M/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gKCgUMA8=&rs=AOn4CLCnVbCFKmBuhNsNyW6DRxmtRXFc9Q',
#   17,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485148)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'iroyC8PEyhw',
#   'Czerny_30_01_04 ツェルニー30番練習曲 １番',
#   74,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/iroyC8PEyhw/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQCgZMA8=&rs=AOn4CLAWXCKonR_vUz0jT0EntYDLHZ0u3A',
#   17,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485154)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'JE0dEF-ewvA',
#   'Czerny_30_01_05 ツェルニー30番練習曲 １番',
#   62,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/JE0dEF-ewvA/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gQSgdMA8=&rs=AOn4CLBHPRIWirWYr7gt1tF6pcFf9VLnhA',
#   6,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485161)],
#  ['UCg8J10XW9WOKsGAUxUg5PAg',
#   'JXT15BNDMxo',
#   'Czerny_30_01_06 ツェルニー30番練習曲 １番',
#   51,
#   'ツェルニー30番練習曲 １番独学ピアノ練習https://piano-meister123.fc2.net/blog-entry-11.html',
#   'https://i.ytimg.com/vi/JXT15BNDMxo/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHgCIAC0AWKAgwIABABGH8gNSgXMA8=&rs=AOn4CLBVvSykglY8Nbcw7M6JU9u8Qp914w',
#   5,
#   '3 years ago',
#   datetime.datetime(2024, 8, 23, 13, 47, 36, 485168)]]

# %%
len(channel_video_list)
# Out:
# 878

# %%
#  Iterate through the results to get the title
for video in scrapetube.get_channel("UCgia4xeNJr_VfyNYSlCmWjg", limit=120):
    title = video['title']['runs'][0]['text']
    if "descriptionSnippet" in video:
        descriptionSnippet = video['descriptionSnippet']['runs'][0]['text']
    else:
        descriptionSnippet = ""
    lengthText = video['lengthText']['simpleText']
    thumbnail_url = video['thumbnail']['thumbnails'][0]['url']
    # views = video['viewCountText']['simpleText']
    # video_object_publish_date = video['publishedTimeText']['simpleText']
    print(f"Video Title: {title}")
    print(f"lengthText: {convert_time_to_seconds(lengthText)}")
    print(f"descriptionSnippet: {descriptionSnippet}")
    print(f"thumbnail_url: {thumbnail_url}")
    # print(f"views: {convert_views_to_int(views)}")
    # print(f"video_object_publish_date: {video_object_publish_date}")
# Out:
# Video Title: FLUIR - SOL MARGUELICHE
# lengthText: 224
# descriptionSnippet: #reggaeargentino #reggae  #reggaemusic
#
# En un año marcado por desencuentros laborales, emocionales e institucionales, y por la ausencia de políticas que apoyen el desarrollo profesional,...
# thumbnail_url: https://i.ytimg.com/vi/wLvileX_LvE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGFkgZSgTMA8=&rs=AOn4CLAJulPqGJDul3LFEzsRhEOp71500Q
# Video Title: Diásporas Perdidas feat. Sol Margueliche - Freedom Sounds
# lengthText: 234
# descriptionSnippet: #reggae #freedomsounds #reggaemusic
#
#  Diásporas Perdidas es un gran riddim de Freedom Sounds.
# Mi lirica salió de un chalengue que participe con muchos otrxs artistas y este también quedo...
# thumbnail_url: https://i.ytimg.com/vi/f-1RiElB7OM/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGEEgZChlMA8=&rs=AOn4CLCVXxLCr9Tjy22dnxSctd-ydWeo8g
# Video Title: Natural - Sol Margueliche
# lengthText: 264
# descriptionSnippet: #reggae #reggaeargentina #reggaemusic
# NATURAL
# El abuelo Juan nos decía: El conocimiento sobre las plantas esta ahí, a nivel mundial, podemos elegir buscar, estudiar, informarnos sobre todos...
# thumbnail_url: https://i.ytimg.com/vi/FpkOUei2XKY/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gPighMA8=&rs=AOn4CLC7OMQgaB-iqZ1dWT-EmYZeqfkOxQ
# Video Title: Vivo!
# lengthText: 78
# descriptionSnippet: Bienvenidxs
# Yo Sol Margueliche, compartiendo mis canciones en clave reggae.
# #reggae #reggaeargentina #reggaemusic
#
# 》Registro audiovisual: ACUTUN producciones @acutunproducciones9327
# Dirección...
# thumbnail_url: https://i.ytimg.com/vi/Yla7mqtR0eI/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AG2CIACuAiKAgwIABABGBkgEyh_MA8=&rs=AOn4CLAXJcNxeUu3xX2pwptL2ThKZ7UtHA
# Video Title: Nos Movemos - Sol Margueliche
# lengthText: 214
# descriptionSnippet: #reggaeenespañol #reggae #reggaeargentina
# NOS MOVEMOS
#
# 》Créditos:
# Autora y Compositora: Sol Margueliche
# Productores musicales: Sol Margueliche - Matías Gómez - Juampi Espina
# Teclados/sint...
# thumbnail_url: https://i.ytimg.com/vi/KFtbUWpbuVQ/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGDogZSgPMA8=&rs=AOn4CLAwOFsYyW4R25ykZ356alZiTDGoeg
# Video Title: Un día a la vez - Sol Margueliche
# lengthText: 237
# descriptionSnippet: #reggae #reggaeenespañol #reggaeargentina
# Un día a la vez
#
# 》Créditos:
# Autora y Compositora: Sol Margueliche
# Productores musicales: Sol Margueliche - Matías Gómez - Juampi Espina ...
# thumbnail_url: https://i.ytimg.com/vi/xqitvPzKM-0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGHIgWSgrMA8=&rs=AOn4CLDAk4hQwga9B_rLdh2amr2kMwOy-g
# Video Title: El viaje es Amarte✨🎼 #reggae #acapella #reggaemusic #reggaeroots #amorpropio #voz #solmargueliche
# lengthText: 100
# descriptionSnippet:
# thumbnail_url: https://i.ytimg.com/vi/Yl1aDBTLdyE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AGMAoAC4AOKAgwIABABGHIgRSgqMA8=&rs=AOn4CLBFQgCJflgKtGCVTTaaKsON5Kuhzw
# Video Title: Amarte - Sol Margueliche (FULL EP)
# lengthText: 702
# descriptionSnippet: Escucha Amarte (FULL EP) en todas las plataformas digitales: https://onerpm.link/316299451270
# Amarte 🚀🎼
# 00:00 Nos movemos
# 03:00 Con ilusión
# 05:55 Te escribo
# 09:05 Canciones de...
# thumbnail_url: https://i.ytimg.com/vi/f0yyYrSBcWQ/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGF8gXyhfMA8=&rs=AOn4CLBDR2PGCPQdeCApWaJ3K4FNhTrctg
# Video Title: De ayer y hoy - Sol Margueliche
# lengthText: 176
# descriptionSnippet: #reggae #cover #voice
# SUSCRIBITE ACÁ ▶️https://youtube.com/c/SolMargueliche
# De ayer y de hoy. Tres temas, tres bandas:
# Mix: La Ombú, El Majebri, NegusaNegast
#
# "El reggae” La Ombú...
# thumbnail_url: https://i.ytimg.com/vi/PNn2J1_b3dQ/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgRyg_MA8=&rs=AOn4CLB0ioq4YhA9mEY63AK2Qzuoz21LNg
# Video Title: En el muelle de San Blás (Maná) -Sol Margueliche
# lengthText: 90
# descriptionSnippet: #reggae #version #reggaemusic #mana #canciones
# En este proceso creativo, cantando  "En el muelle de San Blas", @OficialMana encuentro ese viaje a la soledad, esa espera, con la cual seguimos...
# thumbnail_url: https://i.ytimg.com/vi/YnhK6OrNtho/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gMSgvMA8=&rs=AOn4CLClEPoj-JsR1x6FBuYkMWuqKuNufg
# Video Title: Elevo - Fusión Reggae Loops: (Sol Margueliche & Juampi Espina)
# lengthText: 320
# descriptionSnippet: #reggae #loop #live
# Fusión Reggae Loops presenta:  “Elevo”  Live Session
#
# 》Suscribite a este canal oficial de YouTube.
# Misma armonía y este rompecabezas de versos, en la búsqueda...
# thumbnail_url: https://i.ytimg.com/vi/ah7UaDNGZkI/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgUihFMA8=&rs=AOn4CLAai0--htNvvPYFzNEr6QBO69ElHw
# Video Title: El tesoro (El Mató) - Sol Margueliche
# lengthText: 123
# descriptionSnippet: #reggae #cover #reggaemusic
# Podes suscribirte a este canal.
# 》Mientras termino de armar mi próximo disco, les comparto esta versión reggae, reducida de El Mato a un policía motorizado...
# thumbnail_url: https://i.ytimg.com/vi/0CrtISq38Tk/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGGUgSig9MA8=&rs=AOn4CLDIW0us3j2DYFyIt_crSiq3FSXEkQ
# Video Title: Wish you were here - (Pink Floyd) versión español - Sol Margueliche
# lengthText: 200
# descriptionSnippet: #pinkfloyd #reggae
# Wish you were here -Versión español - Sol Margueliche
# Suscribiste a este canal oficial de YouTube.
# Les comparto mi versión en español de este gran tema de Pink Floyd,...
# thumbnail_url: https://i.ytimg.com/vi/Tiiowo2Ynxc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGFEgZSg4MA8=&rs=AOn4CLDAnAYFkqazOWrWufjmhiC71s37Lg
# Video Title: Yendo -  Fusión Reggae Loops (Sol Margueliche - Juampi Espina)
# lengthText: 196
# descriptionSnippet: #loops #reggae #fusión
#
# Ensayo en Estudio Santa Espina
# Fusión Reggae Loops
# Es una amalgama de géneros, ritmos, idiomas y herramientas musicales que nos traslada en la historia de la música...
# thumbnail_url: https://i.ytimg.com/vi/f-1diWDSs80/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGHIgXShFMA8=&rs=AOn4CLBBxpfQt_Nw170hlC7JmheeIm1_Kg
# Video Title: I can't help with Azúcar del estero (Sol Margueliche - Juampi Espina)
# lengthText: 241
# descriptionSnippet: #loops   #reggae  #fusion
# Suscribiste a este canal de YouTube.
#
# Ensayo en Estudio Santa Espina. La Plata
# Fusión Reggae Loops
# Es una amalgama de géneros, ritmos, idiomas y herramientas...
# thumbnail_url: https://i.ytimg.com/vi/YTOe_MdBnvc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGHIgXShFMA8=&rs=AOn4CLBW68TUVD3H7BHTDWAuKRrsPKXmaQ
# Video Title: En Clave Reggae - VIVAS NOS QUEREMOS
# lengthText: 262
# descriptionSnippet: #reggaemusic #reggaemusic #catamarca
#
# 》En Clave Reggae: Jueves 10 de Mayo - San Fernando del Valle de Catamarca 2018
# 》El Cebil Hostel https://linktr.ee/elcebil
# 》Producción video:...
# thumbnail_url: https://i.ytimg.com/vi/r1keJ3ID0Nc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC8V_tip66R_66Q8VSRwBnUzSSjXw
# Video Title: En Clave Reggae - SOMOS - CEBIL HOSTEL
# lengthText: 310
# descriptionSnippet: #reggae #reggaemusic  #catamarca
# 》En Clave Reggae - Jueves 10 de Mayo, San Fernando del Valle de Catamarca 2018
# 》El Cebil Hostel https://linktr.ee/elcebil
# 》Producción video: Paula...
# thumbnail_url: https://i.ytimg.com/vi/P3wr-KZ6aeA/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCWNdshOBSkD65gW4I9FFJDgpytEw
# Video Title: EnClaveReggae -Poman- 12 de septiembre de 2017
# lengthText: 264
# descriptionSnippet: EnClaveReggae -Poman- 12 de septiembre de 2017
# Música
#
# Radio Visión, Poman Catamarca.
# thumbnail_url: https://i.ytimg.com/vi/QY1SgRC7_94/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCMhG9pIaT7xO1fun9kZoMe5XXneA
# Video Title: VivoDespertando - Andando
# lengthText: 121
# descriptionSnippet: En la quebrada del valle ancestral.
# Mayo 2017
# Voz Sol Margueliche
# Guitarra Carolina Ibarra
# Bajo Ulises Bulacia
# Batería Matias Calderon
#
# 🔊Desde Catamarca argentina Dejamos la página...
# thumbnail_url: https://i.ytimg.com/vi/BTv7nXb_qJ0/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHeA4AC4AOKAgwIABABGBsgZSgaMA8=&rs=AOn4CLAm54G2mZy193PudjbZj8c7yfmiEg
# Video Title: EnClaveReggae - Somos
# lengthText: 236
# descriptionSnippet: EnClaveReggae  SOMA-2016-
#
# *Somos*
#
# https://web.facebook.com/EnClaveReggae/?fref=ts
#
# Facebook: M Sol Margueliche
#
# San Fernando del Valle de Catamarca - Argentina
#
# "Somos semillas, andando cantando,...
# thumbnail_url: https://i.ytimg.com/vi/xOEDlrfu5gE/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AHuBIAC4AOKAgwIABABGGUgZShlMA8=&rs=AOn4CLAqrsypJmK28A9GDxl6X7ILzQHHBQ
# Video Title: EnClaveReggae - Andando
# lengthText: 185
# descriptionSnippet: EnClaveReggae
# Andando
# Disco: SOMA - 2016 -
#
# https://web.facebook.com/EnClaveReggae/?fref=ts
#
# Facebook: M Sol Margueliche
#
# San Fernando del Valle de Catamarca - Argentina
#
# "Somos semillas,...
# thumbnail_url: https://i.ytimg.com/vi/o-OjfXqb4-o/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLATH7VOINzD7NvIY7G7dmkpdav3JQ
# Video Title: 'Soma' En Clave Reggae - Presentación de disco
# lengthText: 260
# descriptionSnippet: "Somos semillas andando cantando buscando una razón, viviendo momentos, llenos de música linda, en la que estamos despertando."
# ....................
# Audio sonando: "Momentos"
# ......................
# thumbnail_url: https://i.ytimg.com/vi/UdaEYBb1MKc/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLAiZlQ8cMXsyyih6v8Spwdv6KDb7Q
# Video Title: EnClaveReggae - Lindo
# lengthText: 277
# descriptionSnippet: EnClaveReggae  SOMA-2016-
#
# https://web.facebook.com/EnClaveReggae/?fref=ts
#
# Facebook: M Sol Margueliche
#
# San Fernando del Valle de Catamarca - Argentina
#
# "Somos semillas, andando cantando,...
# thumbnail_url: https://i.ytimg.com/vi/Y8orFrsVB6c/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCuvSj3M3qVndjtr_jyrnmJk5_Xvw
# Video Title: Vivo en Teatro Girardi (Catamarca)
# lengthText: 222
# descriptionSnippet: #reggae #catamarca #reggaeargentino
#
# Teatro Girardi. Mientras afinamos. Música, música, música.
# thumbnail_url: https://i.ytimg.com/vi/jTBgZM59Uos/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gEygeMA8=&rs=AOn4CLCWHygi7xH9KFgVfQ_Amp1wTw53yw
# Video Title: En Clave Reggae - Semilla
# lengthText: 314
# descriptionSnippet: En ClaveReggae 28 de Octubre 2016
# Teatro Girardi Festival de bandas Independientes "Catamarca Indie 16"
#
# *Mujer semilla: Marisa Lencina
#
# EnClaveReggae -2016-
#
# https://web.facebook.com/EnClaveRegga...
# thumbnail_url: https://i.ytimg.com/vi/tfgeN1mcqdI/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGH8gMSgYMA8=&rs=AOn4CLCgz44x5pdxoK6-4KN9Mz31lnq8Ag
# Video Title: En Clave Reggae - Andando cantando
# lengthText: 165
# descriptionSnippet: En ClaveReggae 28 de Octubre 2016
# Teatro Girardi Festival de bandas Independientes "Catamarca Indie 16"
# thumbnail_url: https://i.ytimg.com/vi/AJA4V0z1hgc/hqdefault.jpg?sqp=-oaymwE1CKgBEF5IVfKriqkDKAgBFQAAiEIYAXABwAEG8AEB-AH-CYAC0AWKAgwIABABGD4gZSgPMA8=&rs=AOn4CLAhkRPh7_usmYxDUGUIu_8vTdZSrw
# Video Title: Lunáticas en la estación
# lengthText: 120
# descriptionSnippet: Facebook: Muchas Sol Margueliche
#
# También podes escuchar:
# EnClaveReggae -2016-
#
# https://web.facebook.com/EnClaveReggae/?fref=ts
# thumbnail_url: https://i.ytimg.com/vi/SdQSHXBRULk/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCAJfepbI2_j2ZKrLvihhqKVd040w

# %% [markdown]
# ## Multi Process

# %%
import os
import multiprocessing

# Using os module
num_cpu_cores = os.cpu_count()

# Using multiprocessing module
num_cpu_cores = multiprocessing.cpu_count()

print(f"Number of CPU cores: {num_cpu_cores}")

# %%
import concurrent.futures

# Function to sum a range of numbers
def sum_range(start, end):
    return sum(range(start, end + 1))

# Main function to sum 1 to 100 using parallel execution
def parallel_sum():
    ranges = [(1, 25), (26, 50), (51, 75), (76, 100)]  # Split the range into chunks
    total_sum = 0

    with concurrent.futures.ThreadPoolExecutor() as executor:
        # Submit tasks to the executor
        future_to_range = {executor.submit(sum_range, start, end): (start, end) for start, end in ranges}
        
        for future in concurrent.futures.as_completed(future_to_range):
            start, end = future_to_range[future]
            try:
                result = future.result()
                print(f"Sum of range {start} to {end} is {result}")
                total_sum += result
            except Exception as exc:
                print(f"Generated an exception: {exc}")

    return total_sum

# Execute the parallel sum
if __name__ == "__main__":
    total = parallel_sum()
    print(f"Total sum from 1 to 100 is {total}")

# %%
import requests
import random

# List of proxy servers
proxies = [
    {"http": "http://username:password@proxy1.example.com:port"},
    {"http": "http://username:password@proxy2.example.com:port"},
    {"http": "http://username:password@proxy3.example.com:port"},
    # Add more proxies as needed
]

# Your loop where each iteration uses a different proxy
for i in range(100):  # Adjust the range as needed
    proxy = random.choice(proxies)
    try:
        response = requests.get("http://your-api-endpoint.com", proxies=proxy)
        print(f"Iteration {i} Response: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error with proxy {proxy}: {e}")

    # Add any additional logic here
# Out:
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
