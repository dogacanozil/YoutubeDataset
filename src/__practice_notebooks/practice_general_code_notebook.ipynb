# %% [markdown]
# # Application Project - Computational Social Science

# %% [markdown]
# ## YouTube Channels Dataset Fetch

# %%
import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from datetime import datetime
import pandas as pd
from pytube import Channel
import scrapetube
from utils.string_utils import find_between
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# /var/folders/mx/qyzv6w1s6vvfbglqfp09p6240000gq/T/ipykernel_53343/1017863687.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'dataset', 'input_dataset', 'channel_ids.csv.gz'))
channel_ids = pd.read_csv(dataset_path, compression='gzip')

# %%
channel_ids, channel_ids.count(), type(channel_ids)
# Out:
# (                        channel_id
#  0         UCYt67-MBjYF5Y8RcEAjtq1g
#  1         UCYig0vJRD03a6lkqWrbP8xg
#  2         UCOTXKyzvDOqDGDKhuScHOag
#  3         UC4bEEVSvrNu0i7FQrCMNthw
#  4         UCgia4xeNJr_VfyNYSlCmWjg
#  ...                            ...
#  15597228  UCtVOGvJJGEqpcn4lZihjlHQ
#  15597229  UC9TDkg0OnsdDG5JWmecJuOQ
#  15597230  UC0SokC74Aa8HMXZi1Bf8ksw
#  15597231  UCbE0NjJ-j34J_V8MGuApzxw
#  15597232  UCoVghWAzj3_eDZHLjWxHmrQ
#
#  [15597233 rows x 1 columns],
#  channel_id    15597232
#  dtype: int64,
#  pandas.core.frame.DataFrame)

# %%
channel_ids_as_list = channel_ids['channel_id'].to_list()

# %% [markdown]
# ## Channel Attributes

# %% [markdown]
# ### Example for one youtube channel

# %%
#TEST
index = 79139
first_channel_id = channel_ids_as_list[index]
channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
channel_object = Channel(channel_url)
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2009, 2, 3, 0, 0)

# %%
#Get first 1 id from the id list
first_channel_id = channel_ids_as_list[0]

# %%
channel_url = f"https://www.youtube.com/channel/{first_channel_id}"
# channel_url = "https://www.youtube.com/channel/UCWv0DixLIK_FAMMPk9AU0LA"
# channel_url = "https://www.youtube.com/channel/UCZvJUIAiQROopthP-KTtW7g"
# channel_url = "https://www.youtube.com/channel/UCasyWKltNuQ3bGn29Iep7TA"
channel_url
# Out:
# 'https://www.youtube.com/channel/UCYt67-MBjYF5Y8RcEAjtq1g'

# %%
channel_object = Channel(channel_url)

# %%
channel_object.about_html
# if channel_object == []:
#     print("yes")
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en" darker-dark-theme darker-dark-theme-deprecate system-icons typography typography-spacing><head><script data-id="_gd" nonce="RW8_2hONwMIcyuBHAYJCqQ">window.WIZ_global_data = {"MUE6Ne":"youtube_web","MuJWjd":true,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20241009.10_p0","fPDxwd":[],"iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"188588736":true,"676937399":false,"651175828":false,"653718497":false,"660014094":false},"u4g7r":"%.@.null,1000,2]","xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="RW8_2hONwMIcyuBHAYJCqQ">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20241010.09.00\');</script><script nonce="RW8_2hONwMIcyuBHAYJCqQ">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};\nvar combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn=combinedLineAndColumn+(":"+err["columnNumber"]);var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\\/\\/www.youtube.com\\//g,"");if(replaced.match(/https?:\\/\\/[^/]+\\//))thirdPartyScript=\ntrue;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];var key;for(key in values){var value=\nvalues[key];if(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};\n(function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);var i=0;var n=void 0;for(;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e){throw new Error("Polymer define property failed for "+\nObject.keys(p));}this._nativePrototypes[tag]=p}return p}function handlePolymerError(msg){window.onerror(msg,window.location.href,0,0,new Error(Array.prototy ...

# %%
#Channel ID
channel_id = channel_object.channel_id
# channel_object.about_html

# %%
#Channel name
try:
    channel_object.channel_name
except KeyError as e:
    if "'metadata'" == str(e):
        print(True)

# %%
#Channel Description
channel_about_html = str(channel_object.about_html)
channel_description = find_between(channel_about_html, 'name="description" content="', '"><meta name="keywords"')
channel_description
# Out:
# 'Jeyson official channel.Panamanian artist, singer-songwriter and composer🇵🇦'

# %%
with open("output_test.txt", "w") as file:
    # Write the string to the file
    file.write(channel_about_html)

# %%
#Channel Links
import json
channel_about_html = str(channel_object.about_html)
channels_links_as_string = find_between(channel_about_html, ',"links":', ',"displayCanonicalChannelUrl":')
try:
    channels_links_as_list = json.loads(channels_links_as_string)
except:
    channels_links_as_list = {}
channels_links_per_channel = []
for channel in channels_links_as_list:
    print(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")
    channels_links_per_channel.append(f"{channel['channelExternalLinkViewModel']['title']['content']}: {channel['channelExternalLinkViewModel']['link']['content']}")
# Out:
# Instagram: instagram.com/matalojeyson
# Spotify: open.spotify.com/artist/0ghH5fsPlkf2XIALKJNSsb?si=A1JSNou5R-GZ36Dp2b53yA
# YouTube Music: music.youtube.com/channel/UCrgUKxd5CpW_6Mw-DIPnodQ?feature=share
# Apple Music: music.apple.com/pa/artist/jeyson/1676942069

# %%
channels_links_as_string
# Out:
# '[{"channelExternalLinkViewModel":{"title":{"content":"Instagram"},"link":{"content":"instagram.com/matalojeyson","commandRuns":[{"startIndex":0,"length":26,"onTap":{"innertubeCommand":{"clickTrackingParams":"CAwQobIHGAEiEwiJ0OWcuYyJAxXqXHoFHXfnFPg=","commandMetadata":{"webCommandMetadata":{"url":"https://www.youtube.com/redirect?event=channel_description\\u0026redir_token=QUFFLUhqbXZ3MXJEcmNtWVZBSnFSQTNGbG1tRFFuendnUXxBQ3Jtc0tsWUdJNjN2OGZiVFNHTUJRVE02R240THEtZVFSUGhPLWhCNU14SkRXX0JLVlFoaFE2TVBSLTlqNzBXYThnZXBFbXpGOW5pV3Izek9kelVTNFhjNlA5TndXZVhpUTl4QkJraEVLcHRjbFZpMDZfamJGMA\\u0026q=https%3A%2F%2Fwww.instagram.com%2Fmatalojeyson%2F","webPageType":"WEB_PAGE_TYPE_UNKNOWN","rootVe":83769}},"urlEndpoint":{"url":"https://www.youtube.com/redirect?event=channel_description\\u0026redir_token=QUFFLUhqbXZ3MXJEcmNtWVZBSnFSQTNGbG1tRFFuendnUXxBQ3Jtc0tsWUdJNjN2OGZiVFNHTUJRVE02R240THEtZVFSUGhPLWhCNU14SkRXX0JLVlFoaFE2TVBSLTlqNzBXYThnZXBFbXpGOW5pV3Izek9kelVTNFhjNlA5TndXZVhpUTl4QkJraEVLcHRjbFZpMDZfamJGMA\\u0026q=https%3A%2F%2Fwww.instagram.com%2Fmatalojeyson%2F","target":"TARGET_NEW_WINDOW","nofollow":true}}}}]},"favicon":{"sources":[{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcSfLSwm05yS0BK4Kb28e-NTcQAsNLQfDCkRW2BwGzQ_4QLgT3HvRwy5O9kLRnUU-QhzvJantOSGhq8NOQp7EHd_WEvUNR6WW1Pp0THXuSRzNiJgToeoCA","width":16,"height":16},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcTH22r6JfLoEVSgX7gIeBTsmmcp7AsEm8At_mnY9_tLW9u124DyV4paGEu-QpXmBXqIPcMSTlv8F5UB5GjedwV6-DWtz_zxEicpcXo-pYZ0TEWaecy4uQ","width":24,"height":24},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcSWlv5P_cZjL7BphqIddo1r9qha-mEeR_IrjurxF2rEX92_l8yP2L39z9A5Jz1vDA2t2bGvK7gan4DQhBGo42UC0eOq504-dvGEAXDsbkJix84htkBwug","width":32,"height":32},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcQqzHpvesYBsmdBWDYRugCp85G91_-8BqpRJCqkxzl3sWgZa49u-jBCd5bzJhXJYOZjTQYo5t8mhvsLis-Syy1nIqFtNrFoovCj3bE34cmrKiRjMopfxQ","width":48,"height":48},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcQbTG5M4X0YjLq8kiotXH-dm7lV8FQiy_AcEvfMus3rOAW1C3-GpKJ0jH21fBy6_fVG049HuigmOXlF5dvCjABVv788qacJpWHL6XQI6jnAESfCfD5jvw","width":50,"height":50},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcSFSQsKHXrO5erkzaT2KvuVhN0LpXbPxo4ITKyKnQPSmHOLBkDR8KE0mdsMnLBztoNFQ0MGg9k6cUXhtZ_NY0Y06Mf1ywHug6oQEJlqr2uEyy6xlMLBVA","width":64,"height":64},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcQAvxbIjNz253fBLSmkpLq2bO-583cKsl7RkQaKEyo8BPLR9Q5Qoa0mTvoTABEVktDc6DLw0VcX4Qb82mqZhFgCbyUgV9Ab-f0RFOgvaeQl7inOSfoYfg","width":96,"height":96},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcSRJq-gVmK6yOLCGwtrodHEQYTNRSruRrJmM1scx50X9XzjSHrUqo59LQN9VnVGA1ofDs6YoiHSIaIDbB6vVs9ncfT7rzMsiQf9BOzFu5IMe0Uu5ZkeqL8","width":128,"height":128},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcRkINqbo82T1cgBnz-VGKBEoJa5tQD1diIUOZf2pl7p0nLYa3qlgnPXUeGwFNU8-El3YnYg9s6xeqqBtrOGBIVRweP-BLTrMGe7FahdVTOaqEdwCwqZteg","width":180,"height":180},{"url":"https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn:ANd9GcRMnk5lytM1g9HJQSf7bM5Xfi4yFD5Vyri4jzLc1D4JUjmBYMab9mUK04YRfRwyHmDMutbz5OgS4cg_9Z2lEmyotPVb3TDyE7YkLlpC2ywK7bDnmpmQTRw","width":256,"height":256}]}}},{"channelExternalLinkViewModel":{"title":{"content":"Spotify"},"link":{"content":"open.spotify.com/artist/0ghH5fsPlkf2XIALKJNSsb?si=A1JSNou5R-GZ36Dp2b53yA","commandRuns":[{"startIndex":0,"length":72,"onTap":{"innertubeCommand":{"clickTrackingParams":"CAsQobIHGAIiEwiJ0OWcuYyJAxXqXHoFHXfnFPg=","commandMetadata":{"webCommandMetadata":{"url":"https://www.youtube.com/redirect?event=channel_description\\u0026redir_token=QUFFLUhqbGVSNE9SYVFQOTFQWlZWNUUtNVgxRE1rblZ0UXxBQ3Jtc0tuMmRFVGpYWVZTb2RKdkNqSE1qN1lIbjMtMExqbVdqb2k0SjA0d0JEejFWQ2VsMmUzOWJFUy1TVWM1RjRxbDZqVkxxRVpoaHNaZkM1OUx0VDVXek90bjAteEg5dzZzc3pHblF1V24tSGZJT2lMVEMwRQ\\u0026q=https%3A%2F%2Fopen.spotify.com%2Fartist%2F0ghH5fsPlkf2XIALKJNSsb%3Fsi%3DA1JSNou5R-GZ36Dp2b53yA","webPageType":"WEB_PAGE_TYPE_UNKN ...

# %%
#Channel yt api key might be important
channel_object.yt_api_key
# Out:
# 'AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8'

# %%
#Channel Subscribers
channel_about_html = str(channel_object.about_html)
channel_subscriber = find_between(channel_about_html, '"subscriberCountText":"', ' subscribers')
channel_subscriber
# Out:
# '45.4K'

# %%
#Channel Video Count
channel_about_html = str(channel_object.about_html)
channel_video_count = int(find_between(channel_about_html, ',"videoCountText":"', ' videos",').replace(',' , ''))
channel_video_count
# Out:
# 23

# %%
#Channel View Count
channel_about_html = str(channel_object.about_html)
channel_view_count = int(find_between(channel_about_html, ',"viewCountText":"', ' views",').replace(',' , ''))
channel_view_count
# Out:
# 21606500

# %%
time_as_str = find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , '')

# %%
time_as_str
# Out:
# 'Mar 3 2023'

# %%
#Channel creation Date
channel_about_html = str(channel_object.about_html)
channel_creation_date = datetime.strptime(find_between(channel_about_html, 'joinedDateText":{"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2023, 3, 3, 0, 0)

# %%
# Open the file in read mode
with open('output.txt', 'r') as file:
    # Read the entire file into a variable
    content = file.read()

# Now you can use the 'content' variable
temp = content

# %%
#Channel creation Date
channel_about_html = str(temp)
channel_creation_date = datetime.strptime(find_between(channel_about_html, '"content":"Joined ', '","styleRuns"').replace(',' , ''), "%b %d %Y")
channel_creation_date
# Out:
# datetime.datetime(2013, 4, 4, 0, 0)

# %%
#Channel Country
channel_about_html = str(channel_object.about_html)
channel_country = find_between(channel_about_html, '"country":"', '","')
channel_country
# Out:
# 'South Korea'

# %%
channel_object.channel_id, channel_object.channel_name, channel_description, channels_links_per_channel, channel_subscriber, videos_list_per_channel

# %% [markdown]
# ## Video Attributes

# %%
from pytube import YouTube

# %%
vide_url = "https://www.youtube.com/watch?v=NIq14KtuVaM"

# %%
video_object = YouTube(vide_url)

# %%
video_object.title, video_object.author, video_object.publish_date, video_object.thumbnail_url, video_object.length

# %% [markdown]
# ## ScrapeTube - Youtube Channel- Video By Sampling

# %%
def convert_time_to_seconds(time_string):
    # Split the time string by ':'
    time_parts = list(map(int, time_string.split(':')))
    
    # Initialize total_seconds
    total_seconds = 0

    # If the format is hh:mm:ss
    if len(time_parts) == 3:
        hours, minutes, seconds = time_parts
        total_seconds = (hours * 3600) + (minutes * 60) + seconds

    # If the format is mm:ss
    elif len(time_parts) == 2:
        minutes, seconds = time_parts
        total_seconds = (minutes * 60) + seconds

    # If the format is just seconds
    elif len(time_parts) == 1:
        total_seconds = time_parts[0]

    return total_seconds

# Example usage
time_strings = ["96:00:00", "12:00", "25"]

for time_string in time_strings:
    seconds = convert_time_to_seconds(time_string)
    print(f"{time_string} -> {seconds} seconds")


# Example usage
time_string = "96:00:00"
seconds = convert_time_to_seconds(time_string)
print(f"{time_string} -> {seconds} seconds")


def convert_views_to_int(view_string):
    # Remove non-numeric characters
    numeric_string = ''.join(filter(str.isdigit, view_string))
    # Convert the numeric string to an integer
    return int(numeric_string)

# Example usage
view_string = "15,218 views"
views = convert_views_to_int(view_string)
print(f"{view_string} -> {views} views")
# Out:
# 96:00:00 -> 345600 seconds
# 12:00 -> 720 seconds
# 25 -> 25 seconds
# 96:00:00 -> 345600 seconds
# 15,218 views -> 15218 views

# %%
trial_df = pd.read_csv('dataset/output_dataset/from_2000_until_10000_channels_list.csv.gz', compression='gzip')
channel_ids_df = trial_df[1160:1170]
threshold = 120
channel_ids_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 trial_df = pd.read_csv('dataset/output_dataset/from_2000_until_10000_channels_list.csv.gz', compression='gzip')
#       2 channel_ids_df = trial_df[1150:1170]
#       3 threshold = 120
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/common.py:765, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     761 if compression == "gzip":
#     762     if isinstance(handle, str):
#     763         # error: Incompatible types in assignment (expression has type
#     764         # "GzipFile", variable has type "Union[str, BaseBuffer]")
# --> 765         handle = gzip.GzipFile(  # type: ignore[assignment]
#     766             filename=handle,
#     767             mode=ioargs.mode,
#     768             **compression_args,
#     769         )
#     770     else:
#     771         handle = gzip.GzipFile(
#     772             # No overload variant of "GzipFile" matches argument types
#     773             # "Union[str, BaseBuffer]", "str", "Dict[str, Any]"
#    (...)
#     776             **compression_args,
#     777         )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/gzip.py:174, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172     mode += 'b'
#     173 if fileobj is None:
# --> 174     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175 if filename is None:
#     176     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/output_dataset/from_2000_until_10000_channels_list.csv.gz'

# %%
# channel_video_list =[]
# channel_index = 0
# for row in channel_ids_df.itertuples():
#     print(channel_index)
#     channel_index = channel_index+1
#     if row.is_active is True:
#         video_count = 0
#         channel_set = set()
#         for video in scrapetube.get_channel(row.channel_id, limit=threshold):
#             video_count=video_count+1
#         if video_count == threshold:
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='popular')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                            
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'], view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='newest')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#             videos = scrapetube.get_channel(row.channel_id, limit=threshold//3, sort_by='oldest')
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video['videoId'] not in channel_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])
#                         channel_set.add(video['videoId'])
#         else:
#             videos = scrapetube.get_channel(row.channel_id)
#             for video in videos:
#                 current_time = datetime.now()
#                 if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
#                     if video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                        
#                         if "descriptionSnippet" in video:
#                             video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
#                         else:
#                             video_description = ""
                            
#                         if "upcomingEventData" in video:
#                             view_count = None
#                             publish_date = None
#                         elif video['viewCountText']['simpleText']=="No views":
#                             view_count = 0
#                             publish_date = video['publishedTimeText']['simpleText']
#                         else:
#                             view_count = convert_views_to_int(video['viewCountText']['simpleText'])
#                             publish_date = video['publishedTimeText']['simpleText']
                        
#                         if 'title' in video:
#                             if 'runs' in video['title']:
#                                 video_title = video['title']['runs'][0]['text']
#                             elif 'simpleText' in video['title']:
#                                 video_title = video['title']['simpleText']
#                         else:
#                             video_title = None
                            
#                         channel_video_list.append([row.channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'],  view_count, publish_date, current_time])

# %%
video_list = []
video_set = set()
#  Iterate through the results to get the title
# channel_id = 'UCTe-2aKRMD9ydrZcF9WnVQg'
channel_id = row.channel_id

for video in scrapetube.get_channel(channel_id, limit=300):
        current_time = datetime.now()
        if 'thumbnailOverlays' in video:
            if 'thumbnailOverlayTimeStatusRenderer' in video["thumbnailOverlays"][0]:
                if video['videoId'] not in video_set and video["thumbnailOverlays"][0]["thumbnailOverlayTimeStatusRenderer"]["style"]!='LIVE':
                    
                    if "descriptionSnippet" in video:
                        video_description = video["descriptionSnippet"]["runs"][0]["text"].replace("\n", "")
                    else:
                        video_description = ""
                        
                    if "upcomingEventData" in video:
                        view_count = None
                        publish_date = None
                    elif 'viewCountText' not in video:
                        view_count = None
                        publish_date = video['publishedTimeText']['simpleText']
                    elif video['viewCountText']['simpleText']=="No views":
                        view_count = 0
                        publish_date = video['publishedTimeText']['simpleText']
                    else:
                        view_count = convert_views_to_int(video['viewCountText']['simpleText'])
                        publish_date = video['publishedTimeText']['simpleText']
                        
                    if 'title' in video:
                        if 'runs' in video['title']:
                            video_title = video['title']['runs'][0]['text']
                        elif 'simpleText' in video['title']:
                            video_title = video['title']['simpleText']
                    else:
                        video_title = None
                        
                    video_list.append([channel_id, video['videoId'], video_title, convert_time_to_seconds(video['lengthText']['simpleText']), video_description, video['thumbnail']['thumbnails'][0]['url'], view_count, publish_date, current_time])
                    # video_list.append(video)

                    

url = f"https://www.youtube.com/channel/{channel_id}"
url
# Out:
# 'https://www.youtube.com/channel/UCVnBP9vwZ-KhRKP4cpQIiuw'

# %%
video["upcomingEventData"]
# Out:
# {'startTime': '1790712600',
#  'isReminderSet': False,
#  'upcomingEventText': {'runs': [{'text': 'Scheduled for '},
#    {'text': 'DATE_PLACEHOLDER'}]}}

# %%
video_list
# Out:
# []

# %% [markdown]
# ## Multi Process

# %%
import os
import multiprocessing

# Using os module
num_cpu_cores = os.cpu_count()

# Using multiprocessing module
num_cpu_cores = multiprocessing.cpu_count()

print(f"Number of CPU cores: {num_cpu_cores}")

# %%
import concurrent.futures

# Function to sum a range of numbers
def sum_range(start, end):
    return sum(range(start, end + 1))

# Main function to sum 1 to 100 using parallel execution
def parallel_sum():
    ranges = [(1, 25), (26, 50), (51, 75), (76, 100)]  # Split the range into chunks
    total_sum = 0

    with concurrent.futures.ThreadPoolExecutor() as executor:
        # Submit tasks to the executor
        future_to_range = {executor.submit(sum_range, start, end): (start, end) for start, end in ranges}
        
        for future in concurrent.futures.as_completed(future_to_range):
            start, end = future_to_range[future]
            try:
                result = future.result()
                print(f"Sum of range {start} to {end} is {result}")
                total_sum += result
            except Exception as exc:
                print(f"Generated an exception: {exc}")

    return total_sum

# Execute the parallel sum
if __name__ == "__main__":
    total = parallel_sum()
    print(f"Total sum from 1 to 100 is {total}")

# %%
import requests
import random

# List of proxy servers
proxies = [
    {"http": "http://username:password@proxy1.example.com:port"},
    {"http": "http://username:password@proxy2.example.com:port"},
    {"http": "http://username:password@proxy3.example.com:port"},
    # Add more proxies as needed
]

# Your loop where each iteration uses a different proxy
for i in range(100):  # Adjust the range as needed
    proxy = random.choice(proxies)
    try:
        response = requests.get("http://your-api-endpoint.com", proxies=proxy)
        print(f"Iteration {i} Response: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error with proxy {proxy}: {e}")

    # Add any additional logic here
# Out:
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy3.example.com:port'}: Failed to parse: http://username:password@proxy3.example.com:port
# Error with proxy {'http': 'http://username:password@proxy1.example.com:port'}: Failed to parse: http://username:password@proxy1.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port
# Error with proxy {'http': 'http://username:password@proxy2.example.com:port'}: Failed to parse: http://username:password@proxy2.example.com:port

# %% [markdown]
# ## Validation Code

# %%
validate_df = pd.read_csv('/Users/canozil/Desktop/Doga Can/YoutubeDataset-1/src/dataset/output_videos_channels_dataset/videos_from_800000_until_810000_channels.csv.gz', compression='gzip')
validate_df.dtypes
# Out:
# channel_id              object
# video_id                object
# video_title             object
# video_length           float64
# video_description       object
# video_thumbnail_url     object
# video_views_count      float64
# video_publish_date      object
# date_of_capture         object
# dtype: object

# %%
validate_df
# Out:
#                       channel_id     video_id  \
# 0       UCHzS3J5zBKYC4t6XpX4L8wg  b6GuUFzYYrw
# 1       UCHzS3J5zBKYC4t6XpX4L8wg  P3dP89j2Huw
# 2       UCHzS3J5zBKYC4t6XpX4L8wg  sWNDRJ1BP5E
# 3       UCHzS3J5zBKYC4t6XpX4L8wg  qQb9CGAYyW4
# 4       UCHzS3J5zBKYC4t6XpX4L8wg  OVliCuOig2U
# ...                          ...          ...
# 336970  UCQfXNkfDYWF5yBkSLZUnPFw  6dDwbhWgTKM
# 336971  UCRzh_wFFg0mtPB-n9EQ0YDA  EWv2F6773ow
# 336972  UCRzh_wFFg0mtPB-n9EQ0YDA  w2v9qRcGM8c
# 336973  UCRzh_wFFg0mtPB-n9EQ0YDA  LbsAB53d95c
# 336974  UCRzh_wFFg0mtPB-n9EQ0YDA  zlbFJAEVEd0
#
#                                               video_title  video_length  \
# 0       فيديو مؤثر لمعناة الشعب الفلسطيني من بطش لكيان...         297.0
# 1       Didine Canon16 feat. Mister You -Sbart Wtal 3d...         204.0
# 2             zman [ليامات بكري] على أغنيةYouppi X Youppi         200.0
# 3       مونتاج مؤثر لإقصاء المنتخب الجزائري من مونديال...         153.0
# 4                             Best Life [AMV] (Naps&Gims)         198.0
# ...                                                   ...           ...
# 336970  Vault of Aphrodite Immortals fenyx Rising- Aph...        2097.0
# 336971    Sainsbury's Big Kiss-In London - 13 August 2016          60.0
# 336972                          FIERCE! on London Live TV         260.0
# 336973  Please Exercise Caution when Approaching Drag ...           7.0
# 336974                                   FIERCE THE MOVIE         187.0
#
#                                         video_description  \
# 0       الحرية لفلسطين غزة القدس 🇵🇸❤️❤️❤️❤️أغنية La li...
# 1                                                     NaN
# 2                                                     NaN
# 3       1...2...3ViVa l'Algérie 🇩🇿🔥🇩🇿🔥❤️#الماتش_يتعاود...
# 4                     subscribe please 🙏🙏🙏اشترك في القناة
# ...                                                   ...
# 336970  Vault of Aphrodite Aphrodite's Essence Immorta...
# 336971  When a security guard at Sainsbury's told same...
# 336972                                www.FIERCEMOVIE.com
# 336973                                www.FIERCEMOVIE.com
# 336974  Directed by Zoe Davis, "FIERCE!" is an excitin...
#
#                                       video_thumbnail_url  video_views_count  \
# 0       https://i.ytimg.com/vi/b6GuUFzYYrw/hqdefault.j...               78.0
# 1       https://i.ytimg.com/vi/P3dP89j2Huw/hqdefault.j...              507.0
# 2       https://i.ytimg.com/vi/sWNDRJ1BP5E/hqdefault.j...               21.0
# 3       https://i.ytimg.com/vi/qQb9CGAYyW4/hqdefault.j...            33856.0
# 4       https://i.ytimg.com/vi/OVliCuOig2U/hqdefault.j...               61.0
# ...                                                   ...                ...
# 336970  https://i.ytimg.com/vi/6dDwbhWgTKM/hqdefault.j...              661.0
# 336971  https://i.ytimg.com/vi/EWv2F6773ow/hqdefault.j...             7513.0
# 336972  https://i.ytimg.com/vi/w2v9qRcGM8c/hqdefault.j...              199.0
# 336973  https://i.ytimg.com/vi/LbsAB53d95c/hqdefault.j...              225.0
# 336974  https://i.ytimg.com/vi/zlbFJAEVEd0/hqdefault.j...            21740.0
#
#        video_publish_date             date_of_capture
# 0             2 years ago  2024-10-05 04:54:06.612384
# 1             2 years ago  2024-10-05 04:54:06.612384
# 2             2 years ago  2024-10-05 04:54:06.612384
# 3             2 years ago  2024-10-05 04:54:06.612384
# 4             2 years ago  2024-10-05 04:54:06.612384
# ...                   ...                         ...
# 336970        3 years ago  2024-10-05 11:58:16.754986
# 336971        8 years ago  2024-10-05 11:58:18.269724
# 336972        9 years ago  2024-10-05 11:58:18.269724
# 336973        9 years ago  2024-10-05 11:58:18.269724
# 336974        9 years ago  2024-10-05 11:58:18.269724
#
# [336975 rows x 9 columns]

# %%
# Example: finding the record with index label 3
row = validate_df.iloc[2355]
print(row)
# Out:
# channel_id                                           UCcIsu4Dq5ugCwEBYoa5KZdw
# channel_name                                                  Divine Voice IC
# channel_description         Nithyamu Ninne  Aaradhinthunu It Is An Adorati...
# channel_links               ['Facebook: facebook.com/profile.php?id=100079...
# channel_video_count                                                    1847.0
# channel_view_count                                                  1196879.0
# channel_subscriber_count                                                7.11K
# channel_country                                                         India
# channel_creation_date                                     2020-08-01 00:00:00
# date_of_capture                                    2024-09-13 11:55:31.047684
# is_active                                                                True
# Name: 2355, dtype: object

# %%
validate_df = pd.read_csv('dataset/output_dataset/videos_from_380000_until_390000_channels.csv.gz', compression='gzip')
validate_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 validate_df = pd.read_csv('dataset/output_dataset/videos_from_380000_until_390000_channels.csv.gz', compression='gzip')
#       2 validate_df.count()
#
# NameError: name 'pd' is not defined

# %%
validate_df['channel_id'].nunique()
# Out:
# 5987

# %%
validate_df
# Out:
#                       channel_id     video_id  \
# 0       UCQJWtTnAHhEG5w4uN0udnUQ  jNUTxvki_d0
# 1       UCQJWtTnAHhEG5w4uN0udnUQ  bOarXIWBtWk
# 2       UCQJWtTnAHhEG5w4uN0udnUQ  9sVoglgJjRg
# 3       UCQJWtTnAHhEG5w4uN0udnUQ  kMy8W0j-Slw
# 4       UCQJWtTnAHhEG5w4uN0udnUQ  v7v1hIkYH24
# ...                          ...          ...
# 303009  UCf4Uq4dAjCV9PhJBNJFrjBQ  cCLzbqFH_Nk
# 303010  UCf4Uq4dAjCV9PhJBNJFrjBQ  jrzggRUxvPg
# 303011  UCf4Uq4dAjCV9PhJBNJFrjBQ  St1GP_FagPI
# 303012  UCf4Uq4dAjCV9PhJBNJFrjBQ  zAro72E0lbI
# 303013  UCf4Uq4dAjCV9PhJBNJFrjBQ  pOlnz2_38-c
#
#                                               video_title  video_length  \
# 0       Hell's Greatest Dad Sing-Along | Hazbin Hotel ...           151
# 1       Respectless Sing-Along | Hazbin Hotel | Prime ...           120
# 2       Loser, Baby Sing-Along | Hazbin Hotel | Prime ...           183
# 3       Hell is Forever Sing-Along | Hazbin Hotel | Pr...           158
# 4       The Lord of the Rings: The Rings of Power – Of...            61
# ...                                                   ...           ...
# 303009  Lady Butterfly almost took my sanity, but I su...           737
# 303010  Ashina Elite - aka fast guy - Sekiro Blind Pla...           160
# 303011  Sekiro: Rooftop man aka Genichiro Ashina - Bli...           735
# 303012  Sekiro: Snake Eyes Shirafuji - Blind Playthrou...           365
# 303013  Sekiro: General Kuranosuke Matsumoto [Blind Pl...           361
#
#                                         video_description  \
# 0       A Dueling Daddy Duet! Music and lyrics by Sam ...
# 1       And Carmilla thought the last extermination wa...
# 2       Get in, Loser, Babies. We're going to karaoke!...
# 3       What was that!? Sorry couldn't hear you over A...
# 4       A new legend begins September 2, 2022 only on ...
# ...                                                   ...
# 303009  During my Blind Playthrough of the lovely game...
# 303010  Yet another (mini) boss. I only died a few tim...
# 303011  This game... This is just mean. This is mean. ...
# 303012  After an impressive death counter at Rooftop G...
# 303013  This game is definitely doing something to my ...
#
#                                       video_thumbnail_url  video_views_count  \
# 0       https://i.ytimg.com/vi/jNUTxvki_d0/hqdefault.j...         60396858.0
# 1       https://i.ytimg.com/vi/bOarXIWBtWk/hqdefault.j...         41496009.0
# 2       https://i.ytimg.com/vi/9sVoglgJjRg/hqdefault.j...         40617101.0
# 3       https://i.ytimg.com/vi/kMy8W0j-Slw/hqdefault.j...         38261871.0
# 4       https://i.ytimg.com/vi/v7v1hIkYH24/hqdefault.j...         31616527.0
# ...                                                   ...                ...
# 303009  https://i.ytimg.com/vi/cCLzbqFH_Nk/hqdefault.j...               95.0
# 303010  https://i.ytimg.com/vi/jrzggRUxvPg/hqdefault.j...               34.0
# 303011  https://i.ytimg.com/vi/St1GP_FagPI/hqdefault.j...               98.0
# 303012  https://i.ytimg.com/vi/zAro72E0lbI/hqdefault.j...               46.0
# 303013  https://i.ytimg.com/vi/pOlnz2_38-c/hqdefault.j...               25.0
#
#        video_publish_date             date_of_capture
# 0            7 months ago  2024-09-23 23:10:13.501440
# 1            8 months ago  2024-09-23 23:10:13.501498
# 2            8 months ago  2024-09-23 23:10:13.501519
# 3            8 months ago  2024-09-23 23:10:13.501534
# 4             2 years ago  2024-09-23 23:10:13.501549
# ...                   ...                         ...
# 303009        5 years ago  2024-09-24 04:59:24.324427
# 303010        5 years ago  2024-09-24 04:59:24.324438
# 303011        5 years ago  2024-09-24 04:59:24.324451
# 303012        5 years ago  2024-09-24 04:59:24.324466
# 303013        5 years ago  2024-09-24 04:59:24.324480
#
# [303014 rows x 9 columns]
